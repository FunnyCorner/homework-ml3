# %% [markdown]
# # <center> Обучение с учителем. Классификация. Практика
#
# ## <center> Прогнозирование оттока клиентов банка

# %% [markdown]
# ## Постановка задачи

# %% [markdown]
# Теперь настало время самостоятельной работы. В рамках самостоятельной работы вам предстоит решить задачу прогнозирования оттока клиентов банка.
#
# > **Примечание.** Вы уже знакомились с этой задачей в модуле по визуализации («PYTHON-13. Визуализация данных») и провели небольшое исследование данных. Вы можете использовать результаты своего исследования для построения модели машинного обучения.
#
# Напомним контекст задачи:
#
# > Некоторый банк обратился к вам за помощью: он хочет разработать кампанию лояльности по удержанию клиентов. Для этого он хочет прогнозировать вероятности оттока клиентов и определять, уйдёт ли клиент в ближайшее время.
#
# Итак, ранее вы провели небольшой разведывательный анализ, познакомились с данными и выявили, чем ушедшие клиенты отличаются от лояльных и как между собой связаны различные признаки, определяющие клиентов. Вы отлично справились с первой задачей, и теперь представители банка предлагают вам построить саму модель машинного обучения, которая будет прогнозировать отток клиентов.
#
# **Ваша задача** - построить классификатор, который позволит своевременно определять уходящих клиентов банка, оценить качество построенных моделей и проинтерпретировать результаты.
#
# Разделим эту задачу на две части:
# * В первой части мы подготовим данные для моделирования и построим простейшую модель логистической регрессии, оценим её качество и проанализируем результаты её работы.
#
# * Во второй части мы займёмся построением моделей дерева решений и случайного леса, сравним их результаты с результатами, полученными на первом этапе, и сделаем финальный вывод.

# %% [markdown]
# Для начала импортируем библиотеки, которые нам понадобятся:

# %%
import numpy as np #для матричных вычислений
import pandas as pd #для анализа и предобработки данных
import matplotlib.pyplot as plt #для визуализации
import seaborn as sns #для визуализации

from sklearn import linear_model #линейные модели
from sklearn import metrics #метрики
from sklearn import model_selection #сплитование выборки
from sklearn import preprocessing #предобработка данных
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler # Импорт MinMaxScale
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %% [markdown]
# Итак, прочитаем нашу таблицу:

# %%
churn_data = pd.read_csv("D:\coding\Машиное обучение\churn.csv")
churn_data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# ## Практика: логистическая регрессия

# %% [markdown]
# В первой части вам предстоит выполнить задания 5.0–5.6. Максимальное количество баллов, которое можно получить, — 9:

# %% [markdown]
# ### Задание 5.0 (не оценивается)
#
# Для полноты задачи проведите небольшой разведывательный анализ данных. Постройте графики распределения целевого признака, диаграммы и графики, показывающие взаимосвязь между исходными признаками и целевым признаком, а также другие диаграммы, иллюстрирующие предоставленные данные.
#
# **Совет:** воспользуйтесь кодом, который вы писали, выполняя задания в модуле «PYTHON-13. Визуализация данных».

# %%
# Ваш код здесь

churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# функция перевода числового признака 'CreditScore' в категориальный
def get_credit_score_rate(credit_sc:int) -> str:
    """ Функция присвоения кредитной категории по кредитному рейтингу

    Args:
        credit_sc (int): числовое значение кредитного рейтинга

    Returns:
        str: категориальное значение кредитного рейтинга
    """
    if credit_sc in range (0, 300)  : return "Deep"
    if credit_sc in range (300, 500): return "Very_Poor"
    if credit_sc in range (500, 601): return "Poor"
    if credit_sc in range (601, 661): return "Fair"
    if credit_sc in range (661, 781): return "Good"
    if credit_sc in range (781, 851): return "Excellent"
    if credit_sc in range (851, 999): return "Top"

# функция перевода числового признака 'Age' в категориальный
def get_age_cat(age:int) -> str:
    """ Функция присвоения возрастной категории по возрасту

    Args:
        age (int): числовое значение возраста

    Returns:
        str: категориальное значение возраста
    """
    if age in range (14, 20) : return "14_20"
    if age in range (21, 26) : return "21_26"
    if age in range (26, 31) : return "31_31"
    if age in range (31, 36) : return "31_36"
    if age in range (36, 41) : return "36_41"
    if age in range (41, 46) : return "41_46"
    if age in range (46, 51) : return "46_51"
    if age in range (51, 56) : return "51_56"
    if age in range (56, 61) : return "56_61"
    if age in range (61, 66) : return "61_66"
    if age in range (66, 71) : return "66_71"
    if age in range (71, 76) : return "71_76"
    if age in range (76, 81) : return "76_81"
    if age in range (81, 86) : return "81_86"
    if age in range (86, 105): return "86_105"

# формирование признака 'CreditScoreCat'
churn_data['CreditScoreCat'] = churn_data['CreditScore'].apply(get_credit_score_rate)

# формирование признака 'AgeCat'
churn_data['AgeCat'] = churn_data['Age'].apply(get_age_cat)

features = ['CreditScoreCat', 'Geography', 'Gender', 'AgeCat', 'Tenure', 'NumOfProducts', 'HasCrCard', 'IsActiveMember']

n = len(features)                                       
fig, axes = plt.subplots(n, 2, figsize=(15, 40))        

# цикл для всех признаков из списка
for i, feature in enumerate(features):
    # сводная таблица
    count_data = (churn_data[feature].value_counts(normalize=True)
        .sort_values(ascending=False)
        .rename('percentage')
        .reset_index()
    )
    # строим количественную столбчатую диаграмму для долевого соотношения каждой из категорий в данных
    count_barplot = sns.barplot(
        data=count_data, 
        x=count_data.index, 
        y='percentage', 
        ax=axes[i][0]
    )
    # поворот меток на оси абсцисс на 45 градусов
    count_barplot.xaxis.set_tick_params(rotation=45)
    # задаём название оси абсцисс
    count_barplot.set(xlabel=feature)

    # строим столбчатую диаграмму доли людей ушедших из банка в зависимости от признака
    mean_barplot = sns.barplot(data=churn_data, x=feature, y='Exited', ax=axes[i][1])
    mean_barplot.xaxis.set_tick_params(rotation=45)
plt.tight_layout();

# %% [markdown]
# основные выводы по каждому признаку:
#
# CreditScoreCat:
# Наибольшая доля клиентов имеет категорию кредитного рейтинга "Fair".
# Клиенты с более низким кредитным рейтингом ("Very_Poor", "Poor", "Fair") чаще уходят из банка по сравнению с клиентами с высоким кредитным рейтингом ("Good", "Excellent").
# Geography:
# Большинство клиентов из Франции, затем идут Германия и Испания.
# У клиентов из Германии самый высокий процент ухода из банка.
# Gender:
# В данных немного больше мужчин, чем женщин.
# Женщины уходят из банка чаще, чем мужчины.
# AgeCat:
# Наибольшая доля клиентов находится в возрастной категории 41-46 лет.
# Клиенты в возрастной категории 46-51 лет и 51-56 лет имеют наибольший процент ухода.
# Tenure:
# Распределение по длительности использования услуг банка относительно равномерное.
# Клиенты с длительностью использования услуг 1 год чаще уходят из банка.
# NumOfProducts:
# Большинство клиентов используют одну или две услуги банка.
# Клиенты, использующие три и четыре услуги, чаще уходят из банка.
# HasCrCard:
# Большинство клиентов имеют кредитную карту.
# Процент ухода клиентов с кредитной картой немного ниже, чем у клиентов без кредитной карты.
# IsActiveMember:
# В данных почти равное количество активных и неактивных клиентов.
# Активные клиенты имеют значительно меньший процент ухода.
# Общие выводы:
# Возраст и длительность использования услуг банка имеют значительное влияние на вероятность ухода клиента.
# Географическое расположение также важно, так как клиенты из Германии чаще уходят из банка.
# Кредитный рейтинг оказывает влияние: клиенты с более низким рейтингом чаще уходят.
# Количество услуг, используемых клиентом, также является важным фактором: клиенты, использующие больше услуг, имеют более высокий процент ухода.
# Активность клиента в банке явно коррелирует с лояльностью: активные клиенты реже уходят.

# %% [markdown]
# В модуле по визуализации мы выяснили, что отток в Германии, Франции и Испании имеет различные показатели. Исследователи, которые уже работали с этим датасетом, пришли к выводу, что наилучшее решение при работе с этими данными — строить модели индивидуально для каждой страны. Мы будем прогнозировать отток в немецком филиале банка. Давайте выделим только данные, относящиеся к Германии:

# %%
churn_data = churn_data[churn_data['Geography'] == 'Germany']
churn_data.shape
# Out:
# (2509, 14)

# %% [markdown]
# Сразу избавимся от заведомо неинформативных признаков: страна, номер строки, идентификатор пользователя и имя клиента.

# %%
churn_data = churn_data.drop(['Geography', 'RowNumber', 'CustomerId', 'Surname'], axis=1)
churn_data.head()
# Out:
#     CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 7           376  Female   29       4  115046.74              4          1
# 15          616    Male   45       3  143129.41              2          0
# 16          653    Male   58       1  132602.88              1          1
# 26          756    Male   36       2  136815.64              1          1
# 28          574  Female   43       3  141349.43              1          1
#
#     IsActiveMember  EstimatedSalary  Exited
# 7                0        119346.88       1
# 15               1         64327.26       0
# 16               0          5097.67       1
# 26               1        170041.95       0
# 28               1        100187.43       0

# %% [markdown]
# Проверим, что в наших данных нет пропусков:

# %%
churn_data.isnull().sum()
# Out:
# CreditScore        0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# Проверим, что в наших данных нет дубликатов:

# %%
churn_data[churn_data.duplicated()].sum()
# Out:
# CreditScore          0
# Gender               0
# Age                  0
# Tenure               0
# Balance            0.0
# NumOfProducts        0
# HasCrCard            0
# IsActiveMember       0
# EstimatedSalary    0.0
# Exited               0
# dtype: object

# %% [markdown]
# ### Задание 5.1 (1 балл)
#
# Давайте сделаем предобработку данных.
#
# Для начала расширим датасет с помощью методов Feature Engineering. Создайте следующие признаки:
# * `BalanceSalaryRatio` — отношение баланса на счетах к заработной плате клиента;
# * `TenureByAge` — отношение времени пользования услугами банка к возрасту клиента;
# * `CreditScoreGivenAge` — отношение кредитного рейтинга к возрасту клиента.
#
# Затем перекодируйте оставшиеся текстовые категориальные признаки в числовые бинарные столбцы.
#
# Выведите основные статистические характеристики полученных признаков.

# %% [markdown]
# **Критерии оценивания:**
# - Задание выполнено верно, учтены все условия (**1 балл**):
#     * приведён код для создания указанных в задании признаков;
#     * приведён код для кодирования категориальных признаков в числовые бинарные столбцы;
#     * приведён код для расчёта основных статистических характеристик полученных признаков.
#
# - Задание выполнено неверно, не учтено одно или несколько условий (**0 баллов**).

# %%
# Ваш код здесь

churn_data['BalanceSalaryRatio'] = churn_data['Balance'] / churn_data['EstimatedSalary']
churn_data['TenureByAge'] = churn_data['Tenure'] / (churn_data['Age'])
churn_data['CreditScoreGivenAge'] = churn_data['CreditScore'] / (churn_data['Age'])

# перекодируем единичный текстовый категориальный признак 'Gender' в бинарный столбец (1 — 'Male', 0 — 'Female')
churn_data['Gender'] = churn_data['Gender'].apply(lambda x: 1 if x=='Male' else 0)
churn_data.head()
# Out:
#     CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 7           376       0   29       4  115046.74              4          1
# 15          616       1   45       3  143129.41              2          0
# 16          653       1   58       1  132602.88              1          1
# 26          756       1   36       2  136815.64              1          1
# 28          574       0   43       3  141349.43              1          1
#
#     IsActiveMember  EstimatedSalary  Exited  BalanceSalaryRatio  TenureByAge  \
# 7                0        119346.88       1            0.963969     0.137931
# 15               1         64327.26       0            2.225020     0.066667
# 16               0          5097.67       1           26.012449     0.017241
# 26               1        170041.95       0            0.804599     0.055556
# 28               1        100187.43       0            1.410850     0.069767
#
#     CreditScoreGivenAge
# 7             12.965517
# 15            13.688889
# 16            11.258621
# 26            21.000000
# 28            13.348837

# %% [markdown]
# Разделим исходный набор данных на матрицу наблюдений `X` (фичи) и столбец ответов `y` (таргет).

# %%
X = churn_data.drop("Exited", axis=1)
y = churn_data["Exited"]

# %% [markdown]
# Прежде чем перейти к этапу разделения выборки на тренировочную и тестовую, давайте посмотрим на сбалансированность данных. Для этого воспользуемся методом `value_counts()` и выведем количество наблюдений каждого из классов в долевом соотношении от общего количества наблюдений:

# %%
y.value_counts(normalize=True)
# Out:
# Exited
# 0    0.675568
# 1    0.324432
# Name: proportion, dtype: float64

# %% [markdown]
# Очевидно, что классы не сбалансированы. Ушедших пользователей 32 %, в то время как лояльных — 68 %.

# %% [markdown]
# **К чему это может привести?**
#
# При разделении набора данных на тренировочный и тестовый может возникнуть такая ситуация, что в тренировочную выборку попадут только лояльные клиенты или их большая часть. Тогда модель может не научиться определять вероятность оттока и качество на тестовой выборке будет неудовлетворительным.
#
# Или противоположная ситуация: в тестовую выборку попадут только лояльные клиенты. Тогда модель будет показывать отличное качество на тестовой выборке, но в реальных условиях она может оказаться бесполезной.
#
# То есть нам нужно сделать так, чтобы в тренировочной и тестовой выборке было одинаковое соотношение лояльных и ушедших клиентов. Такое разбиение выборки называется **стратифицированным**.
#
# Функция `train_test_split()` из библиотеки `sklearn` умеет производить такое разбиение. Для этого в ней предусмотрен параметр `stratify`, который нужно выставить в значение признака, который должен иметь одинаковые соотношения в тренировочной и тестовой выборке. У нас этот признак - это целевой признак y.
#
# Выполним разбиение, установив значение параметра `random_state` на 0:

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    stratify=y, 
    random_state=0
)
print(f'Train shape: {X_train.shape}')
print(f'Test shape: {X_train.shape}')
# Out:
# Train shape: (1881, 12)
# Test shape: (1881, 12)

# %% [markdown]
# Проверим, что число лояльных и ушедших клиентов примерно одинаково в каждой из выборок:

# %%
print(f'Train: \n{y_train.value_counts(normalize=True)}\n')
print(f'Test : \n{y_test.value_counts(normalize=True)}')
# Out:
# Train:
# Exited
# 0    0.675704
# 1    0.324296
# Name: proportion, dtype: float64
#
# Test :
# Exited
# 0    0.675159
# 1    0.324841
# Name: proportion, dtype: float64

# %% [markdown]
# Соотношения одинаковы, а значит, мы можем перейти к следующему шагу.

# %% [markdown]
# ### Задание 5.2 (1 балл)
#
# Позаботьтесь о масштабировании признаков. Проведите нормализацию/стандартизацию матрицы наблюдений `X` с помощью `MinMaxScaler`/`RobustScaler` или `StandardScaler`. Выберите метод самостоятельно.
#
# Обучите один из предложенных скейлеров на тренировочной выборке (вычислите параметры трансформации) и примените трансформацию данных к тренировочной и тестовой выборкам.

# %% [markdown]
# **Критерии оценивания:**
# - Задание выполнено верно, учтены все условия (**1 балл**):
#     * приведён код для создания одного из вариантов скейлеров для масштабирования данных;
#     * приведён код для расчёта параметров трансформации (обучение скейлера) на тренировочной выборке;
#     * приведён код для трансформации тренировочных и тестовых данных (признаков) в соответствии с вычисленными параметрами.
#
# - Задание выполнено неверно, не учтено одно или несколько условий (**0 баллов**).

# %%
# Ваш код здесь

X_train = pd.get_dummies(X_train, drop_first=True)
X_test = pd.get_dummies(X_test, drop_first=True)

# Выровнять колонки X_train и X_test после one-hot encoding
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)

scaler = MinMaxScaler()

# Обучение скейлера на тренировочной выборке
X_train_scaled = scaler.fit_transform(X_train)

# Применение трансформации к тестовой выборке
X_test_scaled = scaler.transform(X_test)

print("Нормализация завершена успешно.")
# Out:
# Нормализация завершена успешно.

# %% [markdown]
# Теперь переходим к моделированию.

# %% [markdown]
# ### Задание 5.3 (1 балл)
#
# Для начала давайте заранее определим метрику, на которую будем ориентироваться.
#
# По условию задачи, наша модель должна своевременно предсказывать отток клиентов. Известно, что для сохранения клиентов банк будет использовать ресурсы колл-центра и клиентам, у которых вероятность оттока наиболее высока, будут сделаны специальные предложения. Ресурсы, выделяемые на сохранение клиентов, ограничены, поэтому нам важно минимизировать количество звонков. Однако в то же время необходимо сохранить как можно больше клиентов.
#
# Таким образом, нам бы хотелось минимизировать как ложноположительные и ложноотрицательные срабатывания модели.
#
# Какую метрику в данной задаче вы будете пытаться улучшить? Обоснуйте свой выбор.

# %% [markdown]
# > Укажите название метрики и обоснования своего выбора здесь
#
# F1 поскольку нам необходимо найти баланс между precision и recall, то требуется агрегированная метрика, зависящая от этих обеих метрик.

# %% [markdown]
# **Критерии оценивания:**
# - Задание выполнено верно, учтены все условия (**1 балл**):
#     * выбрана верная метрика;
#     * приведено развернутое обоснование выбора метрики, и приведенные рассуждения являются верными;
#
# - Задание выполнено неверно, не учтено одно или несколько условий (**0 баллов**).

# %% [markdown]
# > Ваши рассуждения и ответ — *здесь*.
#
# Так как нам, необходимо минимизировать ложноположительную и ложноотрицательную ошибки модели, за это, как раз, отвечают precision и recall, соответственно, и поскольку надо учитывать обе эти метрики, то проще всего, сразу искать "F-меру", она будет максимальна, когда precision и recall будут максимальны.

# %% [markdown]
# ### Задание 5.4 (2 балла)
#
# Обучите модель логистической регрессии (`Logistic Regression`) на тренировочных данных. Позаботьтесь о воспроизводимости результата, установив конкретное значение параметра `random_state` (например, число 42).
#
# Сделайте предсказание меток классов для тренировочной и тестовой выборок.
#
# Рассчитайте значение целевой метрики на тренировочной и тестовой выборках.
#
# Проинтерпретируйте полученные результаты, ответив на следующий вопрос:
# * Как вы считаете, является ли ваша модель переобученной или недообученной?
#
# > **Примечание.** Будем считать, что модель нас не удовлетворяет (считается недообученной), если значение целевой метрики на тестовой выборке меньше 0.5.
#
# **Дополнительное задание:**
#
# Попробуйте поуправлять следующими параметрами модели:
# * `penalty` — тип используемой регуляризации ('l1' — $L_1$-регуляризация, 'l2' — $L_2$-регуляризация);
# * `C` — коэффициент, обратный коэффициенту регуляризации (по умолчанию он равен 1).
#
# Понаблюдайте, как ведут себя метрики в зависимости от типа регуляризации и увеличения/уменьшения значения парамера `C`.

# %% [markdown]
# **Критерии оценивания:**
# - Задание выполнено верно, учтены все условия (**2 балла**):
#     * построена модель логистической регрессии, решающая поставленную задачу;
#     * с помощью полученной модели сформированы предсказания на тренировочной и тестовой выборках;
#     * приведён расчёт выбранной метрики на тренировочных и тестовых данных (метрика должна быть выбрана корректно);
#     * приведён небольшой вывод по полученным результатам, в котором содержится ответ на поставленный в задании вопрос.
#
# - Задание выполнено верно, но не приведён вывод по полученным результатам или вывод является неверным (**1 балл**).
# - Задание выполнено неверно, не учтено несколько условий (**0 баллов**).

# %%
# Ваш код здесь

# создаём объект класса логистической регрессии с SGD
lr = linear_model.LogisticRegression(
    penalty='l1',
    C=5,
    max_iter=1000,
    solver='saga', 
    random_state=42,
);

# обучаем модель — ищем параметры по методу SGD
lr.fit(X_train_scaled, y_train);

# делаем предсказание для тренировочной выборки
y_train_pred_lr = lr.predict(X_train_scaled)

# делаем предсказание для тестовой выборки
y_test_pred_lr = lr.predict(X_test_scaled)

## вывод отчета о метриках классификации
# ТРЕНИРОВОЧНАЯ ВЫБОРКА
print(f'Train data "F1 score": {metrics.f1_score(y_train, y_train_pred_lr):.3f}')
print(metrics.classification_report(y_train, y_train_pred_lr))

# ТЕСТОВАЯ ВЫБОРКА
print(f'Test data "F1 score": {metrics.f1_score(y_test, y_test_pred_lr):.3f}')
print(metrics.classification_report(y_test, y_test_pred_lr))
# Out:
# LogisticRegression(C=5, max_iter=1000, penalty='l1', random_state=42,
#                    solver='saga')
# Train data "F1 score": 0.516
#               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.82      1271
#            1       0.63      0.44      0.52       610
#
#     accuracy                           0.73      1881
#    macro avg       0.70      0.66      0.67      1881
# weighted avg       0.72      0.73      0.72      1881
#
# Test data "F1 score": 0.496
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81       424
#            1       0.60      0.42      0.50       204
#
#     accuracy                           0.72       628
#    macro avg       0.68      0.64      0.65       628
# weighted avg       0.71      0.72      0.71       628

# %% [markdown]
# > Ваши выводы и рассуждения — *здесь*.
#
# Тип регуляризации - penalty='l1', при применении penalty='l2' модель показывает результат несколько хуже на 2-3 знаке после запятой при комбинации вместе с solver='saga';
# Коэффициент C: C=5, при C =1
#  показывает результат несколько хуже на 2-3 знаке после запятой;
# Метод оптимизации функции потерь - solver='saga', единственный параметр при котором возможно построение модели при комбинации вместе с penalty='l1';
# Максимальное число итераций - max_iter=1000, при значении от 20 до 85 - результат ухудшается по сравнению со стандартным значением, результат улучшается на 2-3 знаке после запятой при увеличении max_iter, после 85 - результат не меняется.

# %% [markdown]
# ### Задание 5.5 (2 балла)
#
# Сгенерируйте полиномиальные признаки третьей степени для тренировочной и тестовой выборок. Используйте класс `PolynomialFeatures` из библиотеки `sklearn`. Параметр `include_bias` выставите в значение `False`.
#
# > **Примечание.** Обратите внимание, что для генерации полиномов необходимо использовать масштабированные данные.
#
# Обучите модель логистической регрессии на полиномиальных признаках (`Logistic Regression`). Позаботьтесь о воспроизводимости результат, установив конкретное значение параметра `random_state` (например, число 42).
#
# Предскажите метки классов для тренировочной и тестовой выборок.
#
# Рассчитайте значение целевой метрики на тренировочной и тестовой выборках для модели, обученной на полиномиальных признаках.
#
# Сравните результат с полученным ранее. Удалось ли вам улучшить качество вашей модели?
#
# **Дополнительное задание:**
#
# Попробуйте поуправлять следующими параметрами модели:
# * `penalty` — тип используемой регуляризации ('l1' — $L_1$-регуляризация, 'l2' — $L_2$-регуляризация);
# * `C` — коэффициент, обратный коэффициенту регуляризации (по умолчанию он равен 1).
#
# Понаблюдайте, как ведут себя метрики в зависимости от типа регуляризации и увеличения/уменьшения значения парамера `C`.

# %% [markdown]
# **Критерии оценивания:**
# - Задание выполнено верно, учтены все условия (**2 балла**):
#     * сгенерированы полиномиальные признаки третьей степени;
#     * построена модель логистической регрессии, решающая поставленную задачу на основе сгенерированных признаков;
#     * с помощью полученной модели сформированы предсказания на тренировочной и тестовой выборках;
#     * приведён расчёт выбранной метрики на тренировочных и тестовых данных (метрика должна быть выбрана корректно);
#     * приведён небольшой вывод по полученным результатам, в котором содержится корректный ответ на поставленный в задании вопрос.
#
# - Задание выполнено верно, но не приведён вывод по полученным результатам или вывод является неверным (**1 балл**).
# - Задание выполнено неверно, не учтено несколько условий (**0 баллов**).

# %%
# Ваш код здесь
# создаём генератор полиномиальных признаков
poly = preprocessing.PolynomialFeatures(degree=3, include_bias=False);
poly.fit(X_train_scaled);

# генерируем полиномиальные признаки для тренировочной выборки
X_train_scaled_poly = poly.transform(X_train_scaled)

# генерируем полиномиальные признаки для тестовой выборки
X_test_scaled_poly = poly.transform(X_test_scaled)

# выводим результирующие размерности таблиц
print(f'Train data shape: {X_train_scaled_poly.shape}')
print(f'Test data shape: {X_test_scaled_poly.shape}')

# создаём объект класса логистической регрессии с SGD
lr_poly = linear_model.LogisticRegression(
    penalty='l1',
    C=500,
    max_iter=1000,
    solver='saga', 
    random_state=42,
);

# обучаем модель с полиномиальными коэффициентами — ищем параметры по методу SGD
lr_poly.fit(X_train_scaled_poly, y_train);

# делаем предсказание на тренировочной выборке
y_train_pred_lr_poly = lr_poly.predict(X_train_scaled_poly)

# делаем предсказание на тестовой выборке
y_test_pred_lr_poly = lr_poly.predict(X_test_scaled_poly)

## вывод отчета о метриках классификации
# ТРЕНИРОВОЧНАЯ ВЫБОРКА
print(f'Train data "F1 score": {metrics.f1_score(y_train, y_train_pred_lr_poly):.3f}')
print(metrics.classification_report(y_train, y_train_pred_lr_poly))

# ТЕСТОВАЯ ВЫБОРКА
print(f'Test data "F1 score": {metrics.f1_score(y_test, y_test_pred_lr_poly):.3f}')
print(metrics.classification_report(y_test, y_test_pred_lr_poly))
# Out:
# PolynomialFeatures(degree=3, include_bias=False)
# Train data shape: (1881, 454)
# Test data shape: (628, 454)
# LogisticRegression(C=500, max_iter=1000, penalty='l1', random_state=42,
#                    solver='saga')
# Train data "F1 score": 0.734
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88      1271
#            1       0.78      0.69      0.73       610
#
#     accuracy                           0.84      1881
#    macro avg       0.82      0.80      0.81      1881
# weighted avg       0.83      0.84      0.83      1881
#
# Test data "F1 score": 0.680
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86       424
#            1       0.71      0.65      0.68       204
#
#     accuracy                           0.80       628
#    macro avg       0.78      0.76      0.77       628
# weighted avg       0.80      0.80      0.80       628

# %% [markdown]
# > Ваши выводы и рассуждения — *здесь*
#
# Тип регуляризации - penalty='l1'. При использовании penalty='l2' модель показывает результат немного хуже на 2-3 знаке после запятой в сочетании с solver='saga'. Коэффициент регуляризации C=0.1 показывает результат несколько хуже на 1-2 знаке после запятой, а дальнейшее увеличение выше 500 не приводит к улучшению результата. Метод оптимизации функции потерь - solver='saga', единственный параметр, при котором возможно построение модели с penalty='l1'. Максимальное число итераций - max_iter=1000. При увеличении числа итераций с 100 результат улучшается на 2-3 знаке после запятой по сравнению со стандартным значением max_iter.
#
# В итоге, модель значительно улучшена по целевой метрике со значением более 0.5. При использовании стандартных параметров модели логистической регрессии (penalty и solver), целевая метрика составляет 0.75 для тренировочной выборки и 0.677 для тестовой. При использовании вышеописанных параметров, модель логистической регрессии показывает метрику 0.734 для тренировочной выборки и улучшает значение для тестовой выборки до 0.68. Эти параметры выбраны как более оптимальные.

# %% [markdown]
# ### Задание 5.6. (2 балла)
#
#
# Попробуйте подобрать значение порога вероятности, при котором наблюдается наибольшее значение целевой метрики на тестовой выборке. В качестве модели используйте логистическую регрессию, обученную на полиномиальных признаках.
#
# В качестве порога вероятности используйте значения из следующего диапазона:
#
# `thresholds = np.arange(0.1, 1, 0.05)`
#
# Напомним алгоритм, как определить оптимальный порог вероятности:
# * Предсказать вероятности оттока для каждого клиента из тестовой выборки.
# * В цикле перебрать значения порогов вероятности threshold:
#     * Сделать предсказание класса по принципу: если вероятность > threshold, то отнести объект к классу 1, в противном случае — к классу 0.
#     * Рассчитать метрику и занести её в заранее созданный список.
#
# Для реализации алгоритма подбора вы можете воспользоваться шаблоном кода, приведённым ниже:
#
# ```python
# # Делаем предсказание вероятности оттока для каждого клиента из тестовой выборки
# y_test_proba_pred = pd.Series(model.predict_proba(X_test_poly)[:, 1])
# # Инициализируем список, куда будем сохранять метрики.
# scores = []
# # Задаём значения порогов вероятности
# thresholds = np.arange(0.1, 1, 0.05)
# # В цикле перебираем значения порогов вероятности
# for threshold in thresholds:
#     # Делаем предсказание
#     y_test_pred_poly = y_test_proba_pred.apply(lambda x: 1 if x > threshold else 0)
#     # Рассчитываем метрику
#     score = # код для вычисления метрики
#     # Добавляем результат в список
#     scores.append(score)
# ```
#
# Постройте график зависимости целевой метрики от порога вероятности. На основе построенного графика определите порог вероятности, которому соответствует наибольшее значение целевой метрики на тестовой выборке.
#
# Сделайте предсказание классов с подобранным оптимальным порогом вероятности. Рассчитайте значение целевой метрики на тестовой выборке и сравните результат с полученными ранее.

# %% [markdown]
# **Критерии оценивания:**
# - Задание выполнено верно, учтены все условия (**2 балла**):
#     * приведён код для построения графика зависимости значения выбранной метрики от порога вероятности;
#     * найден оптимальный порог вероятности, на котором достигается наибольшее значение выбранной метрики на тестовой выборке;
#     * на основе найденного порога вероятности построено предсказание модели для тренировочной и тестовой выборок;
#     * приведён расчёт выбранной метрики на тренировочных и тестовых данных (метрика должна быть выбрана корректно).
#
# - Задание выполнено верно, но не приведён вывод по полученным результатам или вывод является неверным (**1 балл**).
# - Задание выполнено неверно, не учтено несколько условий (**0 баллов**).

# %%
# Ваш код здесь

# нас интересует только второй столбец
y_test_proba_pred = lr_poly.predict_proba(X_test_scaled_poly)[:, 1]

# для удобства завернём numpy-массив в Pandas Series
y_test_proba_pred = pd.Series(y_test_proba_pred)

# создаём списки, в которых будем хранить значения метрик 
recall_scores = []
precision_scores = []
f1_scores = []

# генерируем набор вероятностных порогов в диапазоне от 0.1 до 1
thresholds = np.arange(0.1, 1, 0.05)

# в цикле будем перебирать сгенерированные пороги
for threshold in thresholds:
    # клиентов, для которых вероятность ухода > threshold, относим к классу 1
    # в противном случае — к классу 0
    y_pred = y_test_proba_pred.apply(lambda x: 1 if x > threshold else 0)
    
    # считаем метрики и добавляем их в списки
    recall_scores.append(metrics.recall_score(y_test, y_pred))
    precision_scores.append(metrics.precision_score(y_test, y_pred))
    f1_scores.append(metrics.f1_score(y_test, y_pred))

# визуализируем метрики при различных threshold
fig, ax = plt.subplots(figsize=(12, 6)) # фигура + координатная плоскость

# строим линейный график зависимости recall от threshold
ax.plot(thresholds, recall_scores, label='Recall')

# строим линейный график зависимости precision от threshold
ax.plot(thresholds, precision_scores, label='Precision')

# строим линейный график зависимости F1 от threshold
ax.plot(thresholds, f1_scores, label='F1-score')

# задаём графику название и подписываем оси
ax.set(title='Recall / Precision / F1 dependence on the threshold',
    xlabel='Probability threshold',
    ylabel='Score'
)

# устанавливаем отметки по оси x
ax.set_xticks(thresholds) 

# отображаем легенду
ax.legend();

# %%
# задаём оптимальный порог вероятностей
threshold_opt = 0.44

# клиентов, вероятность ухода которых > 0.44 относим к классу 1, в противном случае — к классу 0
# делаем предсказание на тренировочной выборке
y_train_proba_pred = lr_poly.predict_proba(X_train_scaled_poly)[:, 1]
y_train_proba_pred = pd.Series(y_train_proba_pred)
y_train_pred_lr_poly_opt = y_train_proba_pred.apply(lambda x: 1 if x > threshold_opt else 0)

# делаем предсказание на тестовой выборке
y_test_pred_lr_poly_opt = y_test_proba_pred.apply(lambda x: 1 if x > threshold_opt else 0)

## вывод отчета о метриках классификации
# ТРЕНИРОВОЧНАЯ ВЫБОРКА
print(f'Train data "Accuracy": {metrics.accuracy_score(y_train, y_train_pred_lr_poly_opt):.3f}')
print(f'Train data "Precision": {metrics.precision_score(y_train, y_train_pred_lr_poly_opt):.3f}')
print(f'Train data "Recall": {metrics.recall_score(y_train, y_train_pred_lr_poly_opt):.3f}')
print(f'Train data "F1 score": {metrics.f1_score(y_train, y_train_pred_lr_poly_opt):.3f}')
print(metrics.classification_report(y_train, y_train_pred_lr_poly_opt))

# ТЕСТОВАЯ ВЫБОРКА
print(f'Test data "Accuracy": {metrics.accuracy_score(y_test, y_test_pred_lr_poly_opt):.3f}')
print(f'Test data "Precision": {metrics.precision_score(y_test, y_test_pred_lr_poly_opt):.3f}')
print(f'Test data "Recall": {metrics.recall_score(y_test, y_test_pred_lr_poly_opt):.3f}')
print(f'Test data "F1 score": {metrics.f1_score(y_test, y_test_pred_lr_poly_opt):.3f}')
print(metrics.classification_report(y_test, y_test_pred_lr_poly_opt))
# Out:
# Train data "Accuracy": 0.832
# Train data "Precision": 0.738
# Train data "Recall": 0.748
# Train data "F1 score": 0.743
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88      1271
#            1       0.74      0.75      0.74       610
#
#     accuracy                           0.83      1881
#    macro avg       0.81      0.81      0.81      1881
# weighted avg       0.83      0.83      0.83      1881
#
# Test data "Accuracy": 0.801
# Test data "Precision": 0.685
# Test data "Recall": 0.716
# Test data "F1 score": 0.700
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85       424
#            1       0.69      0.72      0.70       204
#
#     accuracy                           0.80       628
#    macro avg       0.77      0.78      0.78       628
# weighted avg       0.80      0.80      0.80       628

# %% [markdown]
# Заключение:Начиная с вероятности 0.35, визуально образуется так называемая "полка". Перебор значений threshold_opt привел к максимальным результатам по трем метрикам, включая целевую метрику, при значении вероятности 0.44. При этом значении вероятности достигаются максимальные значения следующих метрик:
#
# Accuracy
# Precision
# F1 score
# Фактически, оптимальных значений вероятности - два:
#
# threshold_opt=0.43. Максимальные метрики:
#
# Accuracy
# Recall
# F1 score
# threshold_opt=0.44. Максимальные метрики:
#
# Accuracy
# Precision
# F1 score
# Поскольку нас интересует точность модели (Precision) и максимальная целевая метрика, наилучшие результаты достигаются при значении 0.44. При выбранном значении вероятности предсказание дополнительно улучшено почти на 10%.

# %% [markdown]
# ## Практика: деревья решений и случайный лес

# %% [markdown]
# Мы продолжаем решать задачу прогнозирования оттока клиентов банка.
#
# Ранее мы построили модель логистической регрессии, затем добавили в модель полиномиальные признаки и подобрали оптимальный порог вероятности для логистической регрессии.
#
# > Теперь попробуем решить задачу с помощью деревьев решений и лесов.
#
#
# > **Примечание №1.** Для выполнения дальнейших заданий необходимо совершить уже знакомые шаги предобработки с данными об оттоке клиентов банка, а именно:
# * выделить данные, относящиеся к отделениям банка в Германии;
# * избавиться от заведомо неинформативных признаков;
# * расширить датасет путём добавления новых признаков;
# * разделить выборку на тренировочную и тестовую со стратификацией.
#
# > **Примечание №2.** Деревья решений — алгоритм, способный уловить нелинейные зависимости. Генерация полиномиальных признаков практически не имеет значения.
# Также деревья решений не чувствительны к масштабу признаков. Масштабирование исходных данных не играет роли при построении деревьев решения.
# Поэтому для решения задачи используйте обучающую (`X_train`, `y_train`) и тестовую (`X_test`, `y_test`) выборки без полиномиальных столбцов.

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(
    X, y, 
    stratify=y, 
    random_state=0
)
print('Train shape: {}'.format(X_train.shape))
print('Test shape: {}'.format(X_test.shape))
# Out:
# Train shape: (1881, 12)
# Test shape: (628, 12)

# %% [markdown]
# Импортируем необходимые для выполнения практики модули:

# %%
from sklearn import tree
from sklearn import ensemble

# %% [markdown]
# Приступим! Выполните задания 8.1–8.4.

# %% [markdown]
# ### Задание 8.1. (2 балла)
#
# Обучите на тренировочной выборке дерево решений из библиотеки `sklearn` (`DecisionTreeClassifier`) с неограниченной максимальной глубиной дерева. В качестве критерия информативности используйте энтропию Шеннона, остальные параметры оставьте по умолчанию.
#
# Также позаботьтесь о воспроизводимости результатов, установив конкретное  значение `random_state` (например, число 42).
#
# Сделайте предсказания для тренировочной и тестовой выборок. Рассчитайте значение целевой метрики на каждой из выборок.
#
# Сделайте вывод, ответив на вопрос:
# * Как вы считаете, является полученная модель переобученной или недообученной? Попробуйте дать обоснование, почему так происходит.

# %% [markdown]
# **Критерии оценивания:**
# - Задание выполнено верно, учтены все условия (**2 балла**):
#     * построена модель дерева решений с заданными в условии задачи параметрами;
#     * с помощью полученной модели сформированы предсказания для тренировочной и тестовой выборок;
#     * приведён расчёт выбранной метрики на тренировочных и тестовых данных (метрика должна быть выбрана корректно);
#     * приведён небольшой вывод по полученным результатам, в котором содержится корректный ответ на поставленный в задании вопрос, а также обоснование полученного результата.
#
# - Задание выполнено верно, но не приведено обоснование полученного результата или обоснование является некорректным (**1 балл**).
# - Задание выполнено неверно, не учтено несколько условий (**0 баллов**).

# %%
# Ваш код здесь

# создаём объект класса DecisionTreeClassifier с энтропией Шеннона
dt_clf_bad = tree.DecisionTreeClassifier(
    criterion='entropy',            # критерий информативности
    random_state=42                 # генератор случайных чисел
)

# обучаем дерево решений по алгоритму CART без ограничения его длины
dt_clf_bad.fit(X_train, y_train);

# делаем предсказание класса для "переобученной" модели на тренировочной выборке
y_train_pred_dt_clf_bad = dt_clf_bad.predict(X_train)

# делаем предсказание класса для "переобученной" модели на тестовой выборке
y_test_pred_dt_clf_bad = dt_clf_bad.predict(X_test)

## вывод отчета о метриках классификации
# ТРЕНИРОВОЧНАЯ ВЫБОРКА
print(f'Train data "F1 score": {metrics.f1_score(y_train, y_train_pred_dt_clf_bad):.3f}')
print(metrics.classification_report(y_train, y_train_pred_dt_clf_bad))

# ТЕСТОВАЯ ВЫБОРКА
print(f'Test data "F1 score": {metrics.f1_score(y_test, y_test_pred_dt_clf_bad):.3f}')
print(metrics.classification_report(y_test, y_test_pred_dt_clf_bad))

# посмотрим глубину дерева
print(f'Tree depth level: {dt_clf_bad.get_depth()}')
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)
# Train data "F1 score": 1.000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1271
#            1       1.00      1.00      1.00       610
#
#     accuracy                           1.00      1881
#    macro avg       1.00      1.00      1.00      1881
# weighted avg       1.00      1.00      1.00      1881
#
# Test data "F1 score": 0.569
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.80       424
#            1       0.59      0.55      0.57       204
#
#     accuracy                           0.73       628
#    macro avg       0.69      0.68      0.69       628
# weighted avg       0.72      0.73      0.73       628
#
# Tree depth level: 22

# %%
# %%time

# создаём фигуру для визуализации графа
fig = plt.figure(figsize=(15, 10))

# строим граф дерева решений
tree.plot_tree(
    dt_clf_bad,                                         # объект обученного дерева
    feature_names=X.columns,                            # наименования факторов
    class_names=["0 - Not exit", "1 - Exited"],         # имена классов
    filled=True,                                        # расцветка графа
)
# Out:
# [Text(0.6145580501618123, 0.9782608695652174, 'Age <= 42.5\nentropy = 0.909\nsamples = 1881\nvalue = [1271, 610]\nclass = 0 - Not exit'),
#  Text(0.4294262405609493, 0.9347826086956522, 'NumOfProducts <= 2.5\nentropy = 0.71\nsamples = 1258\nvalue = [1014, 244]\nclass = 0 - Not exit'),
#  Text(0.5219921453613808, 0.9565217391304348, 'True  '),
#  Text(0.29358818770226536, 0.8913043478260869, 'NumOfProducts <= 1.5\nentropy = 0.658\nsamples = 1212\nvalue = [1006, 206]\nclass = 0 - Not exit'),
#  Text(0.1049757281553398, 0.8478260869565217, 'Balance <= 98022.297\nentropy = 0.837\nsamples = 633\nvalue = [464, 169]\nclass = 0 - Not exit'),
#  Text(0.028047464940668825, 0.8043478260869565, 'Age <= 32.5\nentropy = 0.311\nsamples = 125\nvalue = [118, 7]\nclass = 0 - Not exit'),
#  Text(0.023732470334412083, 0.7608695652173914, 'entropy = 0.0\nsamples = 49\nvalue = [49, 0]\nclass = 0 - Not exit'),
#  Text(0.032362459546925564, 0.7608695652173914, 'CreditScore <= 743.0\nentropy = 0.443\nsamples = 76\nvalue = [69, 7]\nclass = 0 - Not exit'),
#  Text(0.028047464940668825, 0.717391304347826, 'CreditScore <= 721.0\nentropy = 0.531\nsamples = 58\nvalue = [51, 7]\nclass = 0 - Not exit'),
#  Text(0.017259978425026967, 0.6739130434782609, 'TenureByAge <= 0.056\nentropy = 0.439\nsamples = 55\nvalue = [50, 5]\nclass = 0 - Not exit'),
#  Text(0.008629989212513484, 0.6304347826086957, 'BalanceSalaryRatio <= 0.499\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]\nclass = 0 - Not exit'),
#  Text(0.004314994606256742, 0.5869565217391305, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.012944983818770227, 0.5869565217391305, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0 - Not exit'),
#  Text(0.025889967637540454, 0.6304347826086957, 'BalanceSalaryRatio <= 0.851\nentropy = 0.337\nsamples = 48\nvalue = [45, 3]\nclass = 0 - Not exit'),
#  Text(0.021574973031283712, 0.5869565217391305, 'entropy = 0.0\nsamples = 31\nvalue = [31, 0]\nclass = 0 - Not exit'),
#  Text(0.030204962243797196, 0.5869565217391305, 'TenureByAge <= 0.164\nentropy = 0.672\nsamples = 17\nvalue = [14, 3]\nclass = 0 - Not exit'),
#  Text(0.025889967637540454, 0.5434782608695652, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = 0 - Not exit'),
#  Text(0.034519956850053934, 0.5434782608695652, 'CreditScore <= 482.5\nentropy = 0.918\nsamples = 9\nvalue = [6, 3]\nclass = 0 - Not exit'),
#  Text(0.030204962243797196, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.038834951456310676, 0.5, 'CreditScore <= 611.0\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]\nclass = 0 - Not exit'),
#  Text(0.034519956850053934, 0.45652173913043476, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0 - Not exit'),
#  Text(0.043149946062567425, 0.45652173913043476, 'TenureByAge <= 0.25\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = 1 - Exited'),
#  Text(0.038834951456310676, 0.41304347826086957, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.04746494066882417, 0.41304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.038834951456310676, 0.6739130434782609, 'Tenure <= 4.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = 1 - Exited'),
#  Text(0.034519956850053934, 0.6304347826086957, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.043149946062567425, 0.6304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.036677454153182305, 0.717391304347826, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]\nclass = 0 - Not exit'),
#  Text(0.1819039913700108, 0.8043478260869565, 'Balance <= 161848.312\nentropy = 0.903\nsamples = 508\nvalue = [346, 162]\nclass = 0 - Not exit'),
#  Text(0.17758899676375406, 0.7608695652173914, 'CreditScoreGivenAge <= 15.575\nentropy = 0.924\nsamples = 477\nvalue = [315, 162]\nclass = 0 - Not exit'),
#  Text(0.0714670981661273, 0.717391304347826, 'TenureByAge <= 0.05\nentropy = 0.995\nsamples = 87\nvalue = [40, 47]\nclass = 1 - Exited'),
#  Text(0.05609492988133765, 0.6739130434782609, 'BalanceSalaryRatio <= 14.075\nentropy = 0.469\nsamples = 20\nvalue = [2, 18]\nclass = 1 - Exited'),
#  Text(0.05177993527508091, 0.6304347826086957, 'Age <= 37.5\nentropy = 0.297\nsamples = 19\nvalue = [1, 18]\nclass = 1 - Exited'),
#  Text(0.04746494066882417, 0.5869565217391305, 'Balance <= 114599.035\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = 1 - Exited'),
#  Text(0.043149946062567425, 0.5434782608695652, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.05177993527508091, 0.5434782608695652, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.05609492988133765, 0.5869565217391305, 'entropy = 0.0\nsamples = 16\nvalue = [0, 16]\nclass = 1 - Exited'),
#  Text(0.06040992448759439, 0.6304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.08683926645091694, 0.6739130434782609, 'TenureByAge <= 0.134\nentropy = 0.987\nsamples = 67\nvalue = [38.0, 29.0]\nclass = 0 - Not exit'),
#  Text(0.06903991370010787, 0.6304347826086957, 'Balance <= 131317.855\nentropy = 0.722\nsamples = 25\nvalue = [20, 5]\nclass = 0 - Not exit'),
#  Text(0.06472491909385113, 0.5869565217391305, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = 0 - Not exit'),
#  Text(0.07335490830636461, 0.5869565217391305, 'HasCrCard <= 0.5\nentropy = 0.94\nsamples = 14\nvalue = [9, 5]\nclass = 0 - Not exit'),
#  Text(0.06903991370010787, 0.5434782608695652, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0 - Not exit'),
#  Text(0.07766990291262135, 0.5434782608695652, 'CreditScoreGivenAge <= 13.837\nentropy = 0.991\nsamples = 9\nvalue = [4, 5]\nclass = 1 - Exited'),
#  Text(0.07335490830636461, 0.5, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1 - Exited'),
#  Text(0.08198489751887811, 0.5, 'CreditScore <= 595.0\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]\nclass = 0 - Not exit'),
#  Text(0.07766990291262135, 0.45652173913043476, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0 - Not exit'),
#  Text(0.08629989212513485, 0.45652173913043476, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.104638619201726, 0.6304347826086957, 'Balance <= 117232.305\nentropy = 0.985\nsamples = 42\nvalue = [18, 24]\nclass = 1 - Exited'),
#  Text(0.09061488673139159, 0.5869565217391305, 'CreditScoreGivenAge <= 14.879\nentropy = 0.414\nsamples = 12\nvalue = [1, 11]\nclass = 1 - Exited'),
#  Text(0.08629989212513485, 0.5434782608695652, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = 1 - Exited'),
#  Text(0.09492988133764833, 0.5434782608695652, 'EstimatedSalary <= 78791.695\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = 0 - Not exit'),
#  Text(0.09061488673139159, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.09924487594390508, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.1186623516720604, 0.5869565217391305, 'CreditScore <= 507.0\nentropy = 0.987\nsamples = 30\nvalue = [17, 13]\nclass = 0 - Not exit'),
#  Text(0.11434735706580366, 0.5434782608695652, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0 - Not exit'),
#  Text(0.12297734627831715, 0.5434782608695652, 'IsActiveMember <= 0.5\nentropy = 0.995\nsamples = 24\nvalue = [11, 13]\nclass = 1 - Exited'),
#  Text(0.10787486515641856, 0.5, 'TenureByAge <= 0.203\nentropy = 0.837\nsamples = 15\nvalue = [4, 11]\nclass = 1 - Exited'),
#  Text(0.09924487594390508, 0.45652173913043476, 'TenureByAge <= 0.195\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = 0 - Not exit'),
#  Text(0.09492988133764833, 0.41304347826086957, 'CreditScoreGivenAge <= 14.293\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = 1 - Exited'),
#  Text(0.09061488673139159, 0.3695652173913043, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.09924487594390508, 0.3695652173913043, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.10355987055016182, 0.41304347826086957, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.11650485436893204, 0.45652173913043476, 'EstimatedSalary <= 20480.11\nentropy = 0.469\nsamples = 10\nvalue = [1, 9]\nclass = 1 - Exited'),
#  Text(0.1121898597626753, 0.41304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.12081984897518878, 0.41304347826086957, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = 1 - Exited'),
#  Text(0.13807982740021574, 0.5, 'TenureByAge <= 0.183\nentropy = 0.764\nsamples = 9\nvalue = [7, 2]\nclass = 0 - Not exit'),
#  Text(0.133764832793959, 0.45652173913043476, 'TenureByAge <= 0.145\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = 1 - Exited'),
#  Text(0.12944983818770225, 0.41304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.13807982740021574, 0.41304347826086957, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.1423948220064725, 0.45652173913043476, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0 - Not exit'),
#  Text(0.2837108953613808, 0.717391304347826, 'EstimatedSalary <= 74141.672\nentropy = 0.875\nsamples = 390\nvalue = [275, 115]\nclass = 0 - Not exit'),
#  Text(0.18985976267529667, 0.6739130434782609, 'Balance <= 150657.836\nentropy = 0.967\nsamples = 140\nvalue = [85, 55]\nclass = 0 - Not exit'),
#  Text(0.18122977346278318, 0.6304347826086957, 'CreditScoreGivenAge <= 27.463\nentropy = 0.988\nsamples = 124\nvalue = [70, 54]\nclass = 0 - Not exit'),
#  Text(0.17691477885652643, 0.5869565217391305, 'CreditScoreGivenAge <= 26.037\nentropy = 0.996\nsamples = 117\nvalue = [63, 54]\nclass = 0 - Not exit'),
#  Text(0.1725997842502697, 0.5434782608695652, 'EstimatedSalary <= 5112.985\nentropy = 0.989\nsamples = 112\nvalue = [63, 49]\nclass = 0 - Not exit'),
#  Text(0.16828478964401294, 0.5, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0 - Not exit'),
#  Text(0.17691477885652643, 0.5, 'Gender <= 0.5\nentropy = 0.996\nsamples = 106\nvalue = [57, 49]\nclass = 0 - Not exit'),
#  Text(0.1574973031283711, 0.45652173913043476, 'CreditScore <= 711.0\nentropy = 0.968\nsamples = 48\nvalue = [19, 29]\nclass = 1 - Exited'),
#  Text(0.14670981661272922, 0.41304347826086957, 'BalanceSalaryRatio <= 17.369\nentropy = 0.999\nsamples = 33\nvalue = [17, 16]\nclass = 0 - Not exit'),
#  Text(0.1423948220064725, 0.3695652173913043, 'BalanceSalaryRatio <= 3.766\nentropy = 0.987\nsamples = 30\nvalue = [17, 13]\nclass = 0 - Not exit'),
#  Text(0.133764832793959, 0.32608695652173914, 'BalanceSalaryRatio <= 1.746\nentropy = 0.949\nsamples = 19\nvalue = [7, 12]\nclass = 1 - Exited'),
#  Text(0.12944983818770225, 0.2826086956521739, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0 - Not exit'),
#  Text(0.13807982740021574, 0.2826086956521739, 'IsActiveMember <= 0.5\nentropy = 0.811\nsamples = 16\nvalue = [4, 12]\nclass = 1 - Exited'),
#  Text(0.133764832793959, 0.2391304347826087, 'CreditScoreGivenAge <= 17.69\nentropy = 0.971\nsamples = 10\nvalue = [4, 6]\nclass = 1 - Exited'),
#  Text(0.12944983818770225, 0.1956521739130435, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1 - Exited'),
#  Text(0.13807982740021574, 0.1956521739130435, 'Balance <= 112046.129\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]\nclass = 0 - Not exit'),
#  Text(0.133764832793959, 0.15217391304347827, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.1423948220064725, 0.15217391304347827, 'Balance <= 141081.273\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]\nclass = 0 - Not exit'),
#  Text(0.13807982740021574, 0.10869565217391304, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0 - Not exit'),
#  Text(0.14670981661272922, 0.10869565217391304, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.1423948220064725, 0.2391304347826087, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = 1 - Exited'),
#  Text(0.15102481121898598, 0.32608695652173914, 'BalanceSalaryRatio <= 13.745\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]\nclass = 0 - Not exit'),
#  Text(0.14670981661272922, 0.2826086956521739, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = 0 - Not exit'),
#  Text(0.1553398058252427, 0.2826086956521739, 'CreditScoreGivenAge <= 19.286\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = 0 - Not exit'),
#  Text(0.15102481121898598, 0.2391304347826087, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.15965480043149946, 0.2391304347826087, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.15102481121898598, 0.3695652173913043, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1 - Exited'),
#  Text(0.16828478964401294, 0.41304347826086957, 'TenureByAge <= 0.044\nentropy = 0.567\nsamples = 15\nvalue = [2, 13]\nclass = 1 - Exited'),
#  Text(0.16396979503775622, 0.3695652173913043, 'Tenure <= 0.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = 0 - Not exit'),
#  Text(0.15965480043149946, 0.32608695652173914, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.16828478964401294, 0.32608695652173914, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.1725997842502697, 0.3695652173913043, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12]\nclass = 1 - Exited'),
#  Text(0.19633225458468176, 0.45652173913043476, 'TenureByAge <= 0.028\nentropy = 0.929\nsamples = 58\nvalue = [38, 20]\nclass = 0 - Not exit'),
#  Text(0.1855447680690399, 0.41304347826086957, 'CreditScoreGivenAge <= 18.255\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]\nclass = 1 - Exited'),
#  Text(0.18122977346278318, 0.3695652173913043, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1 - Exited'),
#  Text(0.18985976267529667, 0.3695652173913043, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.20711974110032363, 0.41304347826086957, 'TenureByAge <= 0.091\nentropy = 0.874\nsamples = 51\nvalue = [36, 15]\nclass = 0 - Not exit'),
#  Text(0.19848975188781015, 0.3695652173913043, 'Age <= 26.0\nentropy = 0.371\nsamples = 14\nvalue = [13, 1]\nclass = 0 - Not exit'),
#  Text(0.1941747572815534, 0.32608695652173914, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.20280474649406688, 0.32608695652173914, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = 0 - Not exit'),
#  Text(0.21574973031283712, 0.3695652173913043, 'Balance <= 103138.965\nentropy = 0.957\nsamples = 37\nvalue = [23, 14]\nclass = 0 - Not exit'),
#  Text(0.21143473570658036, 0.32608695652173914, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1 - Exited'),
#  Text(0.22006472491909385, 0.32608695652173914, 'TenureByAge <= 0.149\nentropy = 0.908\nsamples = 34\nvalue = [23, 11]\nclass = 0 - Not exit'),
#  Text(0.21143473570658036, 0.2826086956521739, 'BalanceSalaryRatio <= 5.3\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]\nclass = 1 - Exited'),
#  Text(0.20711974110032363, 0.2391304347826087, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1 - Exited'),
#  Text(0.21574973031283712, 0.2391304347826087, 'CreditScore <= 600.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = 0 - Not exit'),
#  Text(0.21143473570658036, 0.1956521739130435, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.22006472491909385, 0.1956521739130435, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.22869471413160733, 0.2826086956521739, 'TenureByAge <= 0.203\nentropy = 0.811\nsamples = 28\nvalue = [21, 7]\nclass = 0 - Not exit'),
#  Text(0.2243797195253506, 0.2391304347826087, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = 0 - Not exit'),
#  Text(0.23300970873786409, 0.2391304347826087, 'BalanceSalaryRatio <= 3.086\nentropy = 0.997\nsamples = 15\nvalue = [8, 7]\nclass = 0 - Not exit'),
#  Text(0.22869471413160733, 0.1956521739130435, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1 - Exited'),
#  Text(0.2373247033441208, 0.1956521739130435, 'BalanceSalaryRatio <= 3.887\nentropy = 0.845\nsamples = 11\nvalue = [8, 3]\nclass = 0 - Not exit'),
#  Text(0.23300970873786409, 0.15217391304347827, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0 - Not exit'),
#  Text(0.24163969795037757, 0.15217391304347827, 'CreditScoreGivenAge <= 22.054\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]\nclass = 0 - Not exit'),
#  Text(0.2373247033441208, 0.10869565217391304, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1 - Exited'),
#  Text(0.2459546925566343, 0.10869565217391304, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0 - Not exit'),
#  Text(0.18122977346278318, 0.5434782608695652, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1 - Exited'),
#  Text(0.1855447680690399, 0.5869565217391305, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = 0 - Not exit'),
#  Text(0.19848975188781015, 0.6304347826086957, 'Balance <= 161029.211\nentropy = 0.337\nsamples = 16\nvalue = [15, 1]\nclass = 0 - Not exit'),
#  Text(0.1941747572815534, 0.5869565217391305, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = 0 - Not exit'),
#  Text(0.20280474649406688, 0.5869565217391305, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.3775620280474649, 0.6739130434782609, 'BalanceSalaryRatio <= 1.353\nentropy = 0.795\nsamples = 250\nvalue = [190, 60]\nclass = 0 - Not exit'),
#  Text(0.36893203883495146, 0.6304347826086957, 'Tenure <= 9.5\nentropy = 0.838\nsamples = 217\nvalue = [159, 58]\nclass = 0 - Not exit'),
#  Text(0.36461704422869473, 0.5869565217391305, 'BalanceSalaryRatio <= 1.144\nentropy = 0.854\nsamples = 208\nvalue = [150, 58]\nclass = 0 - Not exit'),
#  Text(0.33225458468176916, 0.5434782608695652, 'BalanceSalaryRatio <= 1.08\nentropy = 0.807\nsamples = 178\nvalue = [134, 44]\nclass = 0 - Not exit'),
#  Text(0.32793959007551243, 0.5, 'Balance <= 135148.328\nentropy = 0.839\nsamples = 164\nvalue = [120, 44]\nclass = 0 - Not exit'),
#  Text(0.2891046386192017, 0.45652173913043476, 'Balance <= 133834.828\nentropy = 0.904\nsamples = 122\nvalue = [83, 39]\nclass = 0 - Not exit'),
#  Text(0.284789644012945, 0.41304347826086957, 'TenureByAge <= 0.137\nentropy = 0.884\nsamples = 119\nvalue = [83, 36]\nclass = 0 - Not exit'),
#  Text(0.2588996763754045, 0.3695652173913043, 'TenureByAge <= 0.029\nentropy = 0.642\nsamples = 49\nvalue = [41.0, 8.0]\nclass = 0 - Not exit'),
#  Text(0.25026968716289105, 0.32608695652173914, 'Balance <= 117141.914\nentropy = 1.0\nsamples = 10\nvalue = [5, 5]\nclass = 0 - Not exit'),
#  Text(0.2459546925566343, 0.2826086956521739, 'CreditScore <= 625.0\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]\nclass = 0 - Not exit'),
#  Text(0.24163969795037757, 0.2391304347826087, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.25026968716289105, 0.2391304347826087, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0 - Not exit'),
#  Text(0.2545846817691478, 0.2826086956521739, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1 - Exited'),
#  Text(0.267529665587918, 0.32608695652173914, 'CreditScore <= 660.5\nentropy = 0.391\nsamples = 39\nvalue = [36, 3]\nclass = 0 - Not exit'),
#  Text(0.2632146709816613, 0.2826086956521739, 'CreditScore <= 655.0\nentropy = 0.61\nsamples = 20\nvalue = [17, 3]\nclass = 0 - Not exit'),
#  Text(0.2588996763754045, 0.2391304347826087, 'TenureByAge <= 0.08\nentropy = 0.485\nsamples = 19\nvalue = [17, 2]\nclass = 0 - Not exit'),
#  Text(0.2545846817691478, 0.1956521739130435, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = 0 - Not exit'),
#  Text(0.2632146709816613, 0.1956521739130435, 'Balance <= 120092.84\nentropy = 0.722\nsamples = 10\nvalue = [8, 2]\nclass = 0 - Not exit'),
#  Text(0.2588996763754045, 0.15217391304347827, 'IsActiveMember <= 0.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = 0 - Not exit'),
#  Text(0.2545846817691478, 0.10869565217391304, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.2632146709816613, 0.10869565217391304, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.267529665587918, 0.15217391304347827, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0 - Not exit'),
#  Text(0.267529665587918, 0.2391304347826087, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.27184466019417475, 0.2826086956521739, 'entropy = 0.0\nsamples = 19\nvalue = [19, 0]\nclass = 0 - Not exit'),
#  Text(0.3106796116504854, 0.3695652173913043, 'EstimatedSalary <= 176875.688\nentropy = 0.971\nsamples = 70\nvalue = [42, 28]\nclass = 0 - Not exit'),
#  Text(0.29341963322545844, 0.32608695652173914, 'CreditScoreGivenAge <= 19.707\nentropy = 0.863\nsamples = 49\nvalue = [35, 14]\nclass = 0 - Not exit'),
#  Text(0.28047464940668826, 0.2826086956521739, 'Balance <= 127320.84\nentropy = 0.989\nsamples = 16\nvalue = [7, 9]\nclass = 1 - Exited'),
#  Text(0.2761596548004315, 0.2391304347826087, 'CreditScoreGivenAge <= 17.568\nentropy = 0.94\nsamples = 14\nvalue = [5, 9]\nclass = 1 - Exited'),
#  Text(0.27184466019417475, 0.1956521739130435, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1 - Exited'),
#  Text(0.28047464940668826, 0.1956521739130435, 'CreditScore <= 642.5\nentropy = 0.991\nsamples = 9\nvalue = [5, 4]\nclass = 0 - Not exit'),
#  Text(0.2761596548004315, 0.15217391304347827, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0 - Not exit'),
#  Text(0.284789644012945, 0.15217391304347827, 'Balance <= 113015.879\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]\nclass = 1 - Exited'),
#  Text(0.28047464940668826, 0.10869565217391304, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1 - Exited'),
#  Text(0.2891046386192017, 0.10869565217391304, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.284789644012945, 0.2391304347826087, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.3063646170442287, 0.2826086956521739, 'CreditScore <= 702.5\nentropy = 0.614\nsamples = 33\nvalue = [28, 5]\nclass = 0 - Not exit'),
#  Text(0.30204962243797195, 0.2391304347826087, 'entropy = 0.0\nsamples = 19\nvalue = [19, 0]\nclass = 0 - Not exit'),
#  Text(0.3106796116504854, 0.2391304347826087, 'TenureByAge <= 0.271\nentropy = 0.94\nsamples = 14\nvalue = [9, 5]\nclass = 0 - Not exit'),
#  Text(0.3063646170442287, 0.1956521739130435, 'EstimatedSalary <= 142197.086\nentropy = 0.811\nsamples = 12\nvalue = [9, 3]\nclass = 0 - Not exit'),
#  Text(0.30204962243797195, 0.15217391304347827, 'Balance <= 109000.422\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]\nclass = 0 - Not exit'),
#  Text(0.2977346278317152, 0.10869565217391304, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.3063646170442287, 0.10869565217391304, 'Balance <= 114707.773\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]\nclass = 0 - Not exit'),
#  Text(0.30204962243797195, 0.06521739130434782, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0 - Not exit'),
#  Text(0.3106796116504854, 0.06521739130434782, 'Balance <= 115349.777\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = 0 - Not exit'),
#  Text(0.3063646170442287, 0.021739130434782608, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.3149946062567422, 0.021739130434782608, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.3106796116504854, 0.15217391304347827, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0 - Not exit'),
#  Text(0.3149946062567422, 0.1956521739130435, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.32793959007551243, 0.32608695652173914, 'EstimatedSalary <= 180219.586\nentropy = 0.918\nsamples = 21\nvalue = [7, 14]\nclass = 1 - Exited'),
#  Text(0.32362459546925565, 0.2826086956521739, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1 - Exited'),
#  Text(0.33225458468176916, 0.2826086956521739, 'EstimatedSalary <= 197591.641\nentropy = 0.977\nsamples = 17\nvalue = [7, 10]\nclass = 1 - Exited'),
#  Text(0.32793959007551243, 0.2391304347826087, 'EstimatedSalary <= 191876.062\nentropy = 1.0\nsamples = 14\nvalue = [7, 7]\nclass = 0 - Not exit'),
#  Text(0.32362459546925565, 0.1956521739130435, 'EstimatedSalary <= 184280.672\nentropy = 0.881\nsamples = 10\nvalue = [3, 7]\nclass = 1 - Exited'),
#  Text(0.3193096008629989, 0.15217391304347827, 'BalanceSalaryRatio <= 0.693\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = 0 - Not exit'),
#  Text(0.3149946062567422, 0.10869565217391304, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0 - Not exit'),
#  Text(0.32362459546925565, 0.10869565217391304, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.32793959007551243, 0.15217391304347827, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = 1 - Exited'),
#  Text(0.33225458468176916, 0.1956521739130435, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0 - Not exit'),
#  Text(0.3365695792880259, 0.2391304347826087, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1 - Exited'),
#  Text(0.29341963322545844, 0.41304347826086957, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1 - Exited'),
#  Text(0.3667745415318231, 0.45652173913043476, 'CreditScoreGivenAge <= 20.378\nentropy = 0.527\nsamples = 42\nvalue = [37, 5]\nclass = 0 - Not exit'),
#  Text(0.36245954692556637, 0.41304347826086957, 'CreditScoreGivenAge <= 19.82\nentropy = 0.755\nsamples = 23\nvalue = [18, 5]\nclass = 0 - Not exit'),
#  Text(0.3581445523193096, 0.3695652173913043, 'TenureByAge <= 0.104\nentropy = 0.592\nsamples = 21\nvalue = [18, 3]\nclass = 0 - Not exit'),
#  Text(0.35382955771305286, 0.32608695652173914, 'Gender <= 0.5\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]\nclass = 0 - Not exit'),
#  Text(0.34951456310679613, 0.2826086956521739, 'TenureByAge <= 0.053\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = 1 - Exited'),
#  Text(0.3451995685005394, 0.2391304347826087, 'Balance <= 139430.055\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = 0 - Not exit'),
#  Text(0.3408845738942826, 0.1956521739130435, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.34951456310679613, 0.1956521739130435, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.35382955771305286, 0.2391304347826087, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.3581445523193096, 0.2826086956521739, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0 - Not exit'),
#  Text(0.36245954692556637, 0.32608695652173914, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = 0 - Not exit'),
#  Text(0.3667745415318231, 0.3695652173913043, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.3710895361380798, 0.41304347826086957, 'entropy = 0.0\nsamples = 19\nvalue = [19, 0]\nclass = 0 - Not exit'),
#  Text(0.3365695792880259, 0.5, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = 0 - Not exit'),
#  Text(0.3969795037756203, 0.5434782608695652, 'CreditScore <= 767.0\nentropy = 0.997\nsamples = 30\nvalue = [16, 14]\nclass = 0 - Not exit'),
#  Text(0.3926645091693635, 0.5, 'Age <= 35.5\nentropy = 0.99\nsamples = 25\nvalue = [11.0, 14.0]\nclass = 1 - Exited'),
#  Text(0.38403451995685006, 0.45652173913043476, 'BalanceSalaryRatio <= 1.344\nentropy = 0.977\nsamples = 17\nvalue = [10, 7]\nclass = 0 - Not exit'),
#  Text(0.37971952535059333, 0.41304347826086957, 'EstimatedSalary <= 101939.445\nentropy = 0.918\nsamples = 15\nvalue = [10, 5]\nclass = 0 - Not exit'),
#  Text(0.37540453074433655, 0.3695652173913043, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0 - Not exit'),
#  Text(0.38403451995685006, 0.3695652173913043, 'BalanceSalaryRatio <= 1.209\nentropy = 0.991\nsamples = 9\nvalue = [4, 5]\nclass = 1 - Exited'),
#  Text(0.37971952535059333, 0.32608695652173914, 'TenureByAge <= 0.22\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]\nclass = 1 - Exited'),
#  Text(0.37540453074433655, 0.2826086956521739, 'CreditScoreGivenAge <= 20.37\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]\nclass = 1 - Exited'),
#  Text(0.3710895361380798, 0.2391304347826087, 'EstimatedSalary <= 111035.691\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = 0 - Not exit'),
#  Text(0.3667745415318231, 0.1956521739130435, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.37540453074433655, 0.1956521739130435, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.37971952535059333, 0.2391304347826087, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1 - Exited'),
#  Text(0.38403451995685006, 0.2826086956521739, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.3883495145631068, 0.32608695652173914, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.3883495145631068, 0.41304347826086957, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.40129449838187703, 0.45652173913043476, 'BalanceSalaryRatio <= 1.281\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]\nclass = 1 - Exited'),
#  Text(0.3969795037756203, 0.41304347826086957, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = 1 - Exited'),
#  Text(0.40560949298813376, 0.41304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.40129449838187703, 0.5, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0 - Not exit'),
#  Text(0.3732470334412082, 0.5869565217391305, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = 0 - Not exit'),
#  Text(0.3861920172599784, 0.6304347826086957, 'Balance <= 153604.633\nentropy = 0.33\nsamples = 33\nvalue = [31, 2]\nclass = 0 - Not exit'),
#  Text(0.3818770226537217, 0.5869565217391305, 'entropy = 0.0\nsamples = 31\nvalue = [31, 0]\nclass = 0 - Not exit'),
#  Text(0.39050701186623515, 0.5869565217391305, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.18621898597626754, 0.7608695652173914, 'entropy = 0.0\nsamples = 31\nvalue = [31, 0]\nclass = 0 - Not exit'),
#  Text(0.48220064724919093, 0.8478260869565217, 'IsActiveMember <= 0.5\nentropy = 0.343\nsamples = 579\nvalue = [542, 37]\nclass = 0 - Not exit'),
#  Text(0.43473570658036675, 0.8043478260869565, 'Balance <= 145156.359\nentropy = 0.47\nsamples = 269\nvalue = [242, 27]\nclass = 0 - Not exit'),
#  Text(0.43042071197411, 0.7608695652173914, 'Balance <= 108438.258\nentropy = 0.531\nsamples = 224\nvalue = [197, 27]\nclass = 0 - Not exit'),
#  Text(0.4099244875943905, 0.717391304347826, 'CreditScoreGivenAge <= 17.748\nentropy = 0.353\nsamples = 105\nvalue = [98, 7]\nclass = 0 - Not exit'),
#  Text(0.40560949298813376, 0.6739130434782609, 'entropy = 0.0\nsamples = 27\nvalue = [27, 0]\nclass = 0 - Not exit'),
#  Text(0.41423948220064727, 0.6739130434782609, 'CreditScoreGivenAge <= 18.097\nentropy = 0.436\nsamples = 78\nvalue = [71, 7]\nclass = 0 - Not exit'),
#  Text(0.4099244875943905, 0.6304347826086957, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.418554476806904, 0.6304347826086957, 'Age <= 41.5\nentropy = 0.35\nsamples = 76\nvalue = [71, 5]\nclass = 0 - Not exit'),
#  Text(0.41423948220064727, 0.5869565217391305, 'Balance <= 87956.191\nentropy = 0.3\nsamples = 75\nvalue = [71, 4]\nclass = 0 - Not exit'),
#  Text(0.4099244875943905, 0.5434782608695652, 'entropy = 0.0\nsamples = 29\nvalue = [29, 0]\nclass = 0 - Not exit'),
#  Text(0.418554476806904, 0.5434782608695652, 'Balance <= 89688.02\nentropy = 0.426\nsamples = 46\nvalue = [42, 4]\nclass = 0 - Not exit'),
#  Text(0.41423948220064727, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.4228694714131607, 0.5, 'CreditScore <= 697.0\nentropy = 0.353\nsamples = 45\nvalue = [42, 3]\nclass = 0 - Not exit'),
#  Text(0.418554476806904, 0.45652173913043476, 'BalanceSalaryRatio <= 0.601\nentropy = 0.575\nsamples = 22\nvalue = [19, 3]\nclass = 0 - Not exit'),
#  Text(0.41423948220064727, 0.41304347826086957, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.4228694714131607, 0.41304347826086957, 'CreditScoreGivenAge <= 25.414\nentropy = 0.286\nsamples = 20\nvalue = [19, 1]\nclass = 0 - Not exit'),
#  Text(0.418554476806904, 0.3695652173913043, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]\nclass = 0 - Not exit'),
#  Text(0.42718446601941745, 0.3695652173913043, 'Balance <= 98342.25\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = 0 - Not exit'),
#  Text(0.4228694714131607, 0.32608695652173914, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.43149946062567424, 0.32608695652173914, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.42718446601941745, 0.45652173913043476, 'entropy = 0.0\nsamples = 23\nvalue = [23, 0]\nclass = 0 - Not exit'),
#  Text(0.4228694714131607, 0.5869565217391305, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.45091693635382957, 0.717391304347826, 'Balance <= 109776.18\nentropy = 0.653\nsamples = 119\nvalue = [99, 20]\nclass = 0 - Not exit'),
#  Text(0.43581445523193096, 0.6739130434782609, 'BalanceSalaryRatio <= 3.082\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]\nclass = 1 - Exited'),
#  Text(0.43149946062567424, 0.6304347826086957, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1 - Exited'),
#  Text(0.4401294498381877, 0.6304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.46601941747572817, 0.6739130434782609, 'EstimatedSalary <= 54387.6\nentropy = 0.565\nsamples = 113\nvalue = [98.0, 15.0]\nclass = 0 - Not exit'),
#  Text(0.4487594390507012, 0.6304347826086957, 'EstimatedSalary <= 53574.176\nentropy = 0.811\nsamples = 32\nvalue = [24, 8]\nclass = 0 - Not exit'),
#  Text(0.4444444444444444, 0.5869565217391305, 'TenureByAge <= 0.092\nentropy = 0.663\nsamples = 29\nvalue = [24, 5]\nclass = 0 - Not exit'),
#  Text(0.43581445523193096, 0.5434782608695652, 'CreditScore <= 668.5\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]\nclass = 0 - Not exit'),
#  Text(0.43149946062567424, 0.5, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0 - Not exit'),
#  Text(0.4401294498381877, 0.5, 'TenureByAge <= 0.055\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]\nclass = 1 - Exited'),
#  Text(0.43581445523193096, 0.45652173913043476, 'TenureByAge <= 0.014\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = 0 - Not exit'),
#  Text(0.43149946062567424, 0.41304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.4401294498381877, 0.41304347826086957, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.4444444444444444, 0.45652173913043476, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1 - Exited'),
#  Text(0.45307443365695793, 0.5434782608695652, 'BalanceSalaryRatio <= 227.137\nentropy = 0.297\nsamples = 19\nvalue = [18, 1]\nclass = 0 - Not exit'),
#  Text(0.4487594390507012, 0.5, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]\nclass = 0 - Not exit'),
#  Text(0.45738942826321466, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.45307443365695793, 0.5869565217391305, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1 - Exited'),
#  Text(0.48327939590075514, 0.6304347826086957, 'CreditScoreGivenAge <= 18.594\nentropy = 0.424\nsamples = 81\nvalue = [74, 7]\nclass = 0 - Not exit'),
#  Text(0.47896440129449835, 0.5869565217391305, 'HasCrCard <= 0.5\nentropy = 0.669\nsamples = 40\nvalue = [33, 7]\nclass = 0 - Not exit'),
#  Text(0.4746494066882416, 0.5434782608695652, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = 0 - Not exit'),
#  Text(0.48327939590075514, 0.5434782608695652, 'Balance <= 120165.219\nentropy = 0.771\nsamples = 31\nvalue = [24, 7]\nclass = 0 - Not exit'),
#  Text(0.46601941747572817, 0.5, 'TenureByAge <= 0.115\nentropy = 0.985\nsamples = 7\nvalue = [3, 4]\nclass = 1 - Exited'),
#  Text(0.4617044228694714, 0.45652173913043476, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.4703344120819849, 0.45652173913043476, 'Balance <= 115330.09\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = 0 - Not exit'),
#  Text(0.46601941747572817, 0.41304347826086957, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.4746494066882416, 0.41304347826086957, 'CreditScore <= 452.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = 1 - Exited'),
#  Text(0.4703344120819849, 0.3695652173913043, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.47896440129449835, 0.3695652173913043, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.5005393743257821, 0.5, 'Balance <= 143712.539\nentropy = 0.544\nsamples = 24\nvalue = [21, 3]\nclass = 0 - Not exit'),
#  Text(0.4962243797195254, 0.45652173913043476, 'TenureByAge <= 0.298\nentropy = 0.426\nsamples = 23\nvalue = [21, 2]\nclass = 0 - Not exit'),
#  Text(0.4919093851132686, 0.41304347826086957, 'CreditScore <= 429.5\nentropy = 0.267\nsamples = 22\nvalue = [21, 1]\nclass = 0 - Not exit'),
#  Text(0.48759439050701187, 0.3695652173913043, 'Age <= 40.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = 0 - Not exit'),
#  Text(0.48327939590075514, 0.32608695652173914, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.4919093851132686, 0.32608695652173914, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.4962243797195254, 0.3695652173913043, 'entropy = 0.0\nsamples = 20\nvalue = [20, 0]\nclass = 0 - Not exit'),
#  Text(0.5005393743257821, 0.41304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.5048543689320388, 0.45652173913043476, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.48759439050701187, 0.5869565217391305, 'entropy = 0.0\nsamples = 41\nvalue = [41, 0]\nclass = 0 - Not exit'),
#  Text(0.43905070118662354, 0.7608695652173914, 'entropy = 0.0\nsamples = 45\nvalue = [45, 0]\nclass = 0 - Not exit'),
#  Text(0.5296655879180151, 0.8043478260869565, 'TenureByAge <= 0.164\nentropy = 0.206\nsamples = 310\nvalue = [300, 10]\nclass = 0 - Not exit'),
#  Text(0.5199568500539374, 0.7608695652173914, 'Balance <= 129585.461\nentropy = 0.277\nsamples = 188\nvalue = [179, 9]\nclass = 0 - Not exit'),
#  Text(0.5156418554476807, 0.717391304347826, 'Age <= 36.5\nentropy = 0.355\nsamples = 134\nvalue = [125, 9]\nclass = 0 - Not exit'),
#  Text(0.5005393743257821, 0.6739130434782609, 'BalanceSalaryRatio <= 2.195\nentropy = 0.167\nsamples = 81\nvalue = [79, 2]\nclass = 0 - Not exit'),
#  Text(0.4962243797195254, 0.6304347826086957, 'entropy = 0.0\nsamples = 58\nvalue = [58, 0]\nclass = 0 - Not exit'),
#  Text(0.5048543689320388, 0.6304347826086957, 'EstimatedSalary <= 43658.916\nentropy = 0.426\nsamples = 23\nvalue = [21, 2]\nclass = 0 - Not exit'),
#  Text(0.5005393743257821, 0.5869565217391305, 'entropy = 0.0\nsamples = 21\nvalue = [21, 0]\nclass = 0 - Not exit'),
#  Text(0.5091693635382956, 0.5869565217391305, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.5307443365695793, 0.6739130434782609, 'Balance <= 114693.758\nentropy = 0.563\nsamples = 53\nvalue = [46, 7]\nclass = 0 - Not exit'),
#  Text(0.5221143473570659, 0.6304347826086957, 'TenureByAge <= 0.16\nentropy = 0.323\nsamples = 34\nvalue = [32, 2]\nclass = 0 - Not exit'),
#  Text(0.517799352750809, 0.5869565217391305, 'CreditScoreGivenAge <= 16.562\nentropy = 0.196\nsamples = 33\nvalue = [32, 1]\nclass = 0 - Not exit'),
#  Text(0.5134843581445523, 0.5434782608695652, 'CreditScoreGivenAge <= 15.963\nentropy = 0.469\nsamples = 10\nvalue = [9, 1]\nclass = 0 - Not exit'),
#  Text(0.5091693635382956, 0.5, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = 0 - Not exit'),
#  Text(0.517799352750809, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.5221143473570659, 0.5434782608695652, 'entropy = 0.0\nsamples = 23\nvalue = [23, 0]\nclass = 0 - Not exit'),
#  Text(0.5264293419633226, 0.5869565217391305, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.5393743257820928, 0.6304347826086957, 'Balance <= 117809.316\nentropy = 0.831\nsamples = 19\nvalue = [14, 5]\nclass = 0 - Not exit'),
#  Text(0.535059331175836, 0.5869565217391305, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.5436893203883495, 0.5869565217391305, 'Balance <= 124880.82\nentropy = 0.672\nsamples = 17\nvalue = [14, 3]\nclass = 0 - Not exit'),
#  Text(0.5393743257820928, 0.5434782608695652, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = 0 - Not exit'),
#  Text(0.5480043149946062, 0.5434782608695652, 'CreditScoreGivenAge <= 18.467\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]\nclass = 0 - Not exit'),
#  Text(0.5436893203883495, 0.5, 'TenureByAge <= 0.138\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]\nclass = 0 - Not exit'),
#  Text(0.5393743257820928, 0.45652173913043476, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0 - Not exit'),
#  Text(0.5480043149946062, 0.45652173913043476, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.552319309600863, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.5242718446601942, 0.717391304347826, 'entropy = 0.0\nsamples = 54\nvalue = [54, 0]\nclass = 0 - Not exit'),
#  Text(0.5393743257820928, 0.7608695652173914, 'TenureByAge <= 0.315\nentropy = 0.069\nsamples = 122\nvalue = [121, 1]\nclass = 0 - Not exit'),
#  Text(0.535059331175836, 0.717391304347826, 'entropy = 0.0\nsamples = 111\nvalue = [111, 0]\nclass = 0 - Not exit'),
#  Text(0.5436893203883495, 0.717391304347826, 'TenureByAge <= 0.322\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]\nclass = 0 - Not exit'),
#  Text(0.5393743257820928, 0.6739130434782609, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.5480043149946062, 0.6739130434782609, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = 0 - Not exit'),
#  Text(0.5652642934196332, 0.8913043478260869, 'BalanceSalaryRatio <= 0.808\nentropy = 0.667\nsamples = 46\nvalue = [8, 38]\nclass = 1 - Exited'),
#  Text(0.5566343042071198, 0.8478260869565217, 'Age <= 34.0\nentropy = 0.985\nsamples = 14\nvalue = [6, 8]\nclass = 1 - Exited'),
#  Text(0.552319309600863, 0.8043478260869565, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0 - Not exit'),
#  Text(0.5609492988133765, 0.8043478260869565, 'TenureByAge <= 0.122\nentropy = 0.722\nsamples = 10\nvalue = [2, 8]\nclass = 1 - Exited'),
#  Text(0.5566343042071198, 0.7608695652173914, 'Age <= 40.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = 0 - Not exit'),
#  Text(0.552319309600863, 0.717391304347826, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.5609492988133765, 0.717391304347826, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.5652642934196332, 0.7608695652173914, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = 1 - Exited'),
#  Text(0.5738942826321467, 0.8478260869565217, 'IsActiveMember <= 0.5\nentropy = 0.337\nsamples = 32\nvalue = [2, 30]\nclass = 1 - Exited'),
#  Text(0.56957928802589, 0.8043478260869565, 'entropy = 0.0\nsamples = 20\nvalue = [0, 20]\nclass = 1 - Exited'),
#  Text(0.5782092772384034, 0.8043478260869565, 'CreditScoreGivenAge <= 18.117\nentropy = 0.65\nsamples = 12\nvalue = [2, 10]\nclass = 1 - Exited'),
#  Text(0.5738942826321467, 0.7608695652173914, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1 - Exited'),
#  Text(0.5825242718446602, 0.7608695652173914, 'BalanceSalaryRatio <= 1.532\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]\nclass = 1 - Exited'),
#  Text(0.5782092772384034, 0.717391304347826, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1 - Exited'),
#  Text(0.5868392664509169, 0.717391304347826, 'BalanceSalaryRatio <= 4.033\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = 0 - Not exit'),
#  Text(0.5825242718446602, 0.6739130434782609, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.5911542610571737, 0.6739130434782609, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.7996898597626753, 0.9347826086956522, 'IsActiveMember <= 0.5\nentropy = 0.978\nsamples = 623\nvalue = [257, 366]\nclass = 1 - Exited'),
#  Text(0.7071239549622438, 0.9565217391304348, '  False'),
#  Text(0.6936353829557713, 0.8913043478260869, 'NumOfProducts <= 1.5\nentropy = 0.83\nsamples = 324\nvalue = [85.0, 239.0]\nclass = 1 - Exited'),
#  Text(0.6407766990291263, 0.8478260869565217, 'Balance <= 171268.602\nentropy = 0.664\nsamples = 220\nvalue = [38, 182]\nclass = 1 - Exited'),
#  Text(0.6364617044228694, 0.8043478260869565, 'Age <= 45.5\nentropy = 0.637\nsamples = 217\nvalue = [35, 182]\nclass = 1 - Exited'),
#  Text(0.6127292340884574, 0.7608695652173914, 'Balance <= 149119.211\nentropy = 0.881\nsamples = 60\nvalue = [18, 42]\nclass = 1 - Exited'),
#  Text(0.6040992448759439, 0.717391304347826, 'EstimatedSalary <= 194907.352\nentropy = 0.818\nsamples = 55\nvalue = [14.0, 41.0]\nclass = 1 - Exited'),
#  Text(0.5997842502696872, 0.6739130434782609, 'EstimatedSalary <= 117039.809\nentropy = 0.772\nsamples = 53\nvalue = [12, 41]\nclass = 1 - Exited'),
#  Text(0.5911542610571737, 0.6304347826086957, 'EstimatedSalary <= 98196.793\nentropy = 0.928\nsamples = 32\nvalue = [11, 21]\nclass = 1 - Exited'),
#  Text(0.5868392664509169, 0.5869565217391305, 'Tenure <= 9.5\nentropy = 0.85\nsamples = 29\nvalue = [8, 21]\nclass = 1 - Exited'),
#  Text(0.5825242718446602, 0.5434782608695652, 'TenureByAge <= 0.067\nentropy = 0.764\nsamples = 27\nvalue = [6, 21]\nclass = 1 - Exited'),
#  Text(0.5782092772384034, 0.5, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = 1 - Exited'),
#  Text(0.5868392664509169, 0.5, 'TenureByAge <= 0.079\nentropy = 0.881\nsamples = 20\nvalue = [6, 14]\nclass = 1 - Exited'),
#  Text(0.5782092772384034, 0.45652173913043476, 'CreditScore <= 729.0\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = 0 - Not exit'),
#  Text(0.5738942826321467, 0.41304347826086957, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0 - Not exit'),
#  Text(0.5825242718446602, 0.41304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.5954692556634305, 0.45652173913043476, 'HasCrCard <= 0.5\nentropy = 0.696\nsamples = 16\nvalue = [3, 13]\nclass = 1 - Exited'),
#  Text(0.5911542610571737, 0.41304347826086957, 'CreditScoreGivenAge <= 15.211\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = 0 - Not exit'),
#  Text(0.5868392664509169, 0.3695652173913043, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.5954692556634305, 0.3695652173913043, 'Gender <= 0.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = 1 - Exited'),
#  Text(0.5911542610571737, 0.32608695652173914, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.5997842502696872, 0.32608695652173914, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.5997842502696872, 0.41304347826086957, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = 1 - Exited'),
#  Text(0.5911542610571737, 0.5434782608695652, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.5954692556634305, 0.5869565217391305, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0 - Not exit'),
#  Text(0.6084142394822006, 0.6304347826086957, 'TenureByAge <= 0.225\nentropy = 0.276\nsamples = 21\nvalue = [1, 20]\nclass = 1 - Exited'),
#  Text(0.6040992448759439, 0.5869565217391305, 'entropy = 0.0\nsamples = 19\nvalue = [0, 19]\nclass = 1 - Exited'),
#  Text(0.6127292340884574, 0.5869565217391305, 'CreditScoreGivenAge <= 16.602\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = 0 - Not exit'),
#  Text(0.6084142394822006, 0.5434782608695652, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.6170442286947141, 0.5434782608695652, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.6084142394822006, 0.6739130434782609, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.6213592233009708, 0.717391304347826, 'Tenure <= 2.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]\nclass = 0 - Not exit'),
#  Text(0.6170442286947141, 0.6739130434782609, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.6256742179072277, 0.6739130434782609, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0 - Not exit'),
# ...
#  Text(0.7901833872707659, 0.6739130434782609, 'Balance <= 94896.559\nentropy = 0.997\nsamples = 116\nvalue = [54.0, 62.0]\nclass = 1 - Exited'),
#  Text(0.7551240560949298, 0.6304347826086957, 'CreditScore <= 614.0\nentropy = 0.469\nsamples = 10\nvalue = [9, 1]\nclass = 0 - Not exit'),
#  Text(0.7508090614886731, 0.5869565217391305, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = 0 - Not exit'),
#  Text(0.7594390507011867, 0.5869565217391305, 'CreditScore <= 624.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = 0 - Not exit'),
#  Text(0.7551240560949298, 0.5434782608695652, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.7637540453074434, 0.5434782608695652, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.8252427184466019, 0.6304347826086957, 'CreditScore <= 653.5\nentropy = 0.984\nsamples = 106\nvalue = [45, 61]\nclass = 1 - Exited'),
#  Text(0.7896440129449838, 0.5869565217391305, 'Balance <= 137013.883\nentropy = 0.927\nsamples = 73\nvalue = [25, 48]\nclass = 1 - Exited'),
#  Text(0.7723840345199569, 0.5434782608695652, 'BalanceSalaryRatio <= 2.657\nentropy = 0.838\nsamples = 56\nvalue = [15, 41]\nclass = 1 - Exited'),
#  Text(0.7637540453074434, 0.5, 'Balance <= 128464.82\nentropy = 0.926\nsamples = 41\nvalue = [14.0, 27.0]\nclass = 1 - Exited'),
#  Text(0.7594390507011867, 0.45652173913043476, 'Balance <= 122096.969\nentropy = 0.977\nsamples = 34\nvalue = [14, 20]\nclass = 1 - Exited'),
#  Text(0.7486515641855448, 0.41304347826086957, 'Tenure <= 5.5\nentropy = 0.877\nsamples = 27\nvalue = [8, 19]\nclass = 1 - Exited'),
#  Text(0.7400215749730313, 0.3695652173913043, 'BalanceSalaryRatio <= 2.542\nentropy = 0.544\nsamples = 16\nvalue = [2, 14]\nclass = 1 - Exited'),
#  Text(0.7357065803667745, 0.32608695652173914, 'CreditScore <= 637.0\nentropy = 0.353\nsamples = 15\nvalue = [1, 14]\nclass = 1 - Exited'),
#  Text(0.7313915857605178, 0.2826086956521739, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]\nclass = 1 - Exited'),
#  Text(0.7400215749730313, 0.2826086956521739, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.7443365695792881, 0.32608695652173914, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.7572815533980582, 0.3695652173913043, 'CreditScoreGivenAge <= 10.835\nentropy = 0.994\nsamples = 11\nvalue = [6, 5]\nclass = 0 - Not exit'),
#  Text(0.7529665587918015, 0.32608695652173914, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0 - Not exit'),
#  Text(0.761596548004315, 0.32608695652173914, 'EstimatedSalary <= 74077.02\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]\nclass = 1 - Exited'),
#  Text(0.7572815533980582, 0.2826086956521739, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.7659115426105717, 0.2826086956521739, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1 - Exited'),
#  Text(0.7702265372168284, 0.41304347826086957, 'CreditScoreGivenAge <= 13.754\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]\nclass = 0 - Not exit'),
#  Text(0.7659115426105717, 0.3695652173913043, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0 - Not exit'),
#  Text(0.7745415318230853, 0.3695652173913043, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.7680690399137001, 0.45652173913043476, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = 1 - Exited'),
#  Text(0.7810140237324703, 0.5, 'BalanceSalaryRatio <= 10.905\nentropy = 0.353\nsamples = 15\nvalue = [1, 14]\nclass = 1 - Exited'),
#  Text(0.7766990291262136, 0.45652173913043476, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13]\nclass = 1 - Exited'),
#  Text(0.785329018338727, 0.45652173913043476, 'CreditScore <= 560.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = 0 - Not exit'),
#  Text(0.7810140237324703, 0.41304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.7896440129449838, 0.41304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.8069039913700108, 0.5434782608695652, 'Balance <= 150242.234\nentropy = 0.977\nsamples = 17\nvalue = [10, 7]\nclass = 0 - Not exit'),
#  Text(0.7982740021574973, 0.5, 'BalanceSalaryRatio <= 0.786\nentropy = 0.469\nsamples = 10\nvalue = [9, 1]\nclass = 0 - Not exit'),
#  Text(0.7939590075512406, 0.45652173913043476, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.8025889967637541, 0.45652173913043476, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = 0 - Not exit'),
#  Text(0.8155339805825242, 0.5, 'CreditScore <= 644.0\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]\nclass = 1 - Exited'),
#  Text(0.8112189859762675, 0.45652173913043476, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1 - Exited'),
#  Text(0.819848975188781, 0.45652173913043476, 'CreditScoreGivenAge <= 13.072\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = 0 - Not exit'),
#  Text(0.8155339805825242, 0.41304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.8241639697950378, 0.41304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.86084142394822, 0.5869565217391305, 'EstimatedSalary <= 185560.133\nentropy = 0.967\nsamples = 33\nvalue = [20, 13]\nclass = 0 - Not exit'),
#  Text(0.8565264293419633, 0.5434782608695652, 'CreditScoreGivenAge <= 15.17\nentropy = 0.992\nsamples = 29\nvalue = [16, 13]\nclass = 0 - Not exit'),
#  Text(0.8457389428263214, 0.5, 'BalanceSalaryRatio <= 0.85\nentropy = 0.932\nsamples = 23\nvalue = [15, 8]\nclass = 0 - Not exit'),
#  Text(0.837108953613808, 0.45652173913043476, 'TenureByAge <= 0.151\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]\nclass = 1 - Exited'),
#  Text(0.8327939590075513, 0.41304347826086957, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1 - Exited'),
#  Text(0.8414239482200647, 0.41304347826086957, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.8543689320388349, 0.45652173913043476, 'Age <= 53.0\nentropy = 0.696\nsamples = 16\nvalue = [13, 3]\nclass = 0 - Not exit'),
#  Text(0.8500539374325782, 0.41304347826086957, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = 0 - Not exit'),
#  Text(0.8586839266450917, 0.41304347826086957, 'EstimatedSalary <= 122375.414\nentropy = 0.918\nsamples = 9\nvalue = [6, 3]\nclass = 0 - Not exit'),
#  Text(0.8543689320388349, 0.3695652173913043, 'CreditScoreGivenAge <= 10.06\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]\nclass = 0 - Not exit'),
#  Text(0.8500539374325782, 0.32608695652173914, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.8586839266450917, 0.32608695652173914, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0 - Not exit'),
#  Text(0.8629989212513485, 0.3695652173913043, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.8673139158576052, 0.5, 'Balance <= 114989.711\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]\nclass = 1 - Exited'),
#  Text(0.8629989212513485, 0.45652173913043476, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.8716289104638619, 0.45652173913043476, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1 - Exited'),
#  Text(0.8651564185544768, 0.5434782608695652, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0 - Not exit'),
#  Text(0.8867313915857605, 0.6739130434782609, 'CreditScoreGivenAge <= 19.104\nentropy = 0.637\nsamples = 31\nvalue = [5, 26]\nclass = 1 - Exited'),
#  Text(0.8824163969795038, 0.6304347826086957, 'EstimatedSalary <= 114719.77\nentropy = 0.567\nsamples = 30\nvalue = [4, 26]\nclass = 1 - Exited'),
#  Text(0.8781014023732471, 0.5869565217391305, 'Gender <= 0.5\nentropy = 0.811\nsamples = 16\nvalue = [4, 12]\nclass = 1 - Exited'),
#  Text(0.8737864077669902, 0.5434782608695652, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = 1 - Exited'),
#  Text(0.8824163969795038, 0.5434782608695652, 'Balance <= 96823.105\nentropy = 0.971\nsamples = 10\nvalue = [4, 6]\nclass = 1 - Exited'),
#  Text(0.8781014023732471, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.8867313915857605, 0.5, 'CreditScoreGivenAge <= 14.464\nentropy = 0.811\nsamples = 8\nvalue = [2, 6]\nclass = 1 - Exited'),
#  Text(0.8824163969795038, 0.45652173913043476, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1 - Exited'),
#  Text(0.8910463861920173, 0.45652173913043476, 'TenureByAge <= 0.061\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = 0 - Not exit'),
#  Text(0.8867313915857605, 0.41304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.895361380798274, 0.41304347826086957, 'CreditScoreGivenAge <= 16.498\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = 1 - Exited'),
#  Text(0.8910463861920173, 0.3695652173913043, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.8996763754045307, 0.3695652173913043, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.8867313915857605, 0.5869565217391305, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]\nclass = 1 - Exited'),
#  Text(0.8910463861920173, 0.6304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.8470873786407767, 0.717391304347826, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0 - Not exit'),
#  Text(0.8514023732470335, 0.7608695652173914, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = 0 - Not exit'),
#  Text(0.9557713052858684, 0.8043478260869565, 'EstimatedSalary <= 183779.102\nentropy = 0.738\nsamples = 120\nvalue = [95, 25]\nclass = 0 - Not exit'),
#  Text(0.9514563106796117, 0.7608695652173914, 'Balance <= 103815.18\nentropy = 0.784\nsamples = 107\nvalue = [82, 25]\nclass = 0 - Not exit'),
#  Text(0.9266450916936354, 0.717391304347826, 'Age <= 54.0\nentropy = 0.371\nsamples = 28\nvalue = [26, 2]\nclass = 0 - Not exit'),
#  Text(0.9223300970873787, 0.6739130434782609, 'entropy = 0.0\nsamples = 17\nvalue = [17, 0]\nclass = 0 - Not exit'),
#  Text(0.9309600862998921, 0.6739130434782609, 'CreditScoreGivenAge <= 10.752\nentropy = 0.684\nsamples = 11\nvalue = [9, 2]\nclass = 0 - Not exit'),
#  Text(0.9266450916936354, 0.6304347826086957, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = 0 - Not exit'),
#  Text(0.9352750809061489, 0.6304347826086957, 'BalanceSalaryRatio <= 1.309\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = 0 - Not exit'),
#  Text(0.9309600862998921, 0.5869565217391305, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.9395900755124056, 0.5869565217391305, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.9762675296655879, 0.717391304347826, 'Balance <= 138038.273\nentropy = 0.87\nsamples = 79\nvalue = [56, 23]\nclass = 0 - Not exit'),
#  Text(0.9611650485436893, 0.6739130434782609, 'Age <= 67.5\nentropy = 0.969\nsamples = 53\nvalue = [32, 21]\nclass = 0 - Not exit'),
#  Text(0.9525350593311759, 0.6304347826086957, 'TenureByAge <= 0.198\nentropy = 0.994\nsamples = 44\nvalue = [24, 20]\nclass = 0 - Not exit'),
#  Text(0.948220064724919, 0.5869565217391305, 'TenureByAge <= 0.165\nentropy = 1.0\nsamples = 41\nvalue = [21, 20]\nclass = 0 - Not exit'),
#  Text(0.9439050701186623, 0.5434782608695652, 'Tenure <= 6.5\nentropy = 0.98\nsamples = 36\nvalue = [21, 15]\nclass = 0 - Not exit'),
#  Text(0.9395900755124056, 0.5, 'Age <= 54.5\nentropy = 0.999\nsamples = 31\nvalue = [16, 15]\nclass = 0 - Not exit'),
#  Text(0.9277238403451996, 0.45652173913043476, 'Balance <= 124396.93\nentropy = 0.971\nsamples = 25\nvalue = [15, 10]\nclass = 0 - Not exit'),
#  Text(0.9169363538295577, 0.41304347826086957, 'TenureByAge <= 0.12\nentropy = 0.779\nsamples = 13\nvalue = [10, 3]\nclass = 0 - Not exit'),
#  Text(0.9083063646170443, 0.3695652173913043, 'Balance <= 104772.906\nentropy = 0.469\nsamples = 10\nvalue = [9, 1]\nclass = 0 - Not exit'),
#  Text(0.9039913700107874, 0.32608695652173914, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.912621359223301, 0.32608695652173914, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = 0 - Not exit'),
#  Text(0.9255663430420712, 0.3695652173913043, 'TenureByAge <= 0.136\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = 1 - Exited'),
#  Text(0.9212513484358145, 0.32608695652173914, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.9298813376483279, 0.32608695652173914, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.9385113268608414, 0.41304347826086957, 'Balance <= 127951.492\nentropy = 0.98\nsamples = 12\nvalue = [5, 7]\nclass = 1 - Exited'),
#  Text(0.9341963322545846, 0.3695652173913043, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1 - Exited'),
#  Text(0.9428263214670982, 0.3695652173913043, 'Balance <= 130704.059\nentropy = 0.991\nsamples = 9\nvalue = [5, 4]\nclass = 0 - Not exit'),
#  Text(0.9385113268608414, 0.32608695652173914, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.9471413160733549, 0.32608695652173914, 'Age <= 43.5\nentropy = 0.985\nsamples = 7\nvalue = [3, 4]\nclass = 1 - Exited'),
#  Text(0.9428263214670982, 0.2826086956521739, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.9514563106796117, 0.2826086956521739, 'Age <= 47.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = 0 - Not exit'),
#  Text(0.9471413160733549, 0.2391304347826087, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0 - Not exit'),
#  Text(0.9557713052858684, 0.2391304347826087, 'CreditScoreGivenAge <= 13.328\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = 1 - Exited'),
#  Text(0.9514563106796117, 0.1956521739130435, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1 - Exited'),
#  Text(0.9600862998921251, 0.1956521739130435, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.9514563106796117, 0.45652173913043476, 'EstimatedSalary <= 55151.215\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]\nclass = 1 - Exited'),
#  Text(0.9471413160733549, 0.41304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.9557713052858684, 0.41304347826086957, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1 - Exited'),
#  Text(0.948220064724919, 0.5, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0 - Not exit'),
#  Text(0.9525350593311759, 0.5434782608695652, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1 - Exited'),
#  Text(0.9568500539374326, 0.5869565217391305, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0 - Not exit'),
#  Text(0.9697950377562028, 0.6304347826086957, 'CreditScoreGivenAge <= 7.505\nentropy = 0.503\nsamples = 9\nvalue = [8, 1]\nclass = 0 - Not exit'),
#  Text(0.9654800431499461, 0.5869565217391305, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.9741100323624595, 0.5869565217391305, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = 0 - Not exit'),
#  Text(0.9913700107874865, 0.6739130434782609, 'Tenure <= 9.5\nentropy = 0.391\nsamples = 26\nvalue = [24, 2]\nclass = 0 - Not exit'),
#  Text(0.9870550161812298, 0.6304347826086957, 'TenureByAge <= 0.021\nentropy = 0.242\nsamples = 25\nvalue = [24, 1]\nclass = 0 - Not exit'),
#  Text(0.982740021574973, 0.5869565217391305, 'TenureByAge <= 0.02\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = 0 - Not exit'),
#  Text(0.9784250269687162, 0.5434782608695652, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0 - Not exit'),
#  Text(0.9870550161812298, 0.5434782608695652, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.9913700107874865, 0.5869565217391305, 'entropy = 0.0\nsamples = 23\nvalue = [23, 0]\nclass = 0 - Not exit'),
#  Text(0.9956850053937433, 0.6304347826086957, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1 - Exited'),
#  Text(0.9600862998921251, 0.7608695652173914, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = 0 - Not exit'),
#  Text(0.910059331175836, 0.8478260869565217, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]\nclass = 1 - Exited')]

# %% [markdown]
# > Ваши выводы и рассуждения — *здесь*
#
# Глубина дерева:Дерево решений имеет значительную глубину, что говорит о высокой сложности модели. Глубокие деревья часто указывают на высокую точность на тренировочных данных, но могут страдать от переобучения.
# Сложность модели:Количество узлов и ветвей показывает, что дерево старается максимально подогнать данные, что также может привести к переобучению. Для улучшения обобщающей способности модели можно рассмотреть обрезку дерева или настройку параметров, таких как минимальное количество выборок на лист или максимальная глубина.
# Важность признаков:По визуализации видно, какие признаки являются наиболее значимыми для принятия решений на каждом уровне дерева. Узлы в верхней части дерева представляют признаки с наибольшим влиянием на предсказания модели.
# Классификация:Цвет узлов (синий и оранжевый) показывает распределение классов (Exited и Not exited). Чем темнее цвет, тем выше чистота узла (узел содержит в основном один класс).
# Границы принятия решений:
#
# В заключении:Модель переобучена, однако:Метрики. Метрики на тренирочной выборке - идеально хороши, метрики на тестовой выборке - идеально плохи;
# Глубина дерева и число ветвей, включая сам граф - нечитабельны, вроде порядок, но, на самом деле - полный хаос;

# %% [markdown]
# ### Задание 8.2. (1 балл)
#
# Давайте «подстрижём» наше дерево.
#
# Обучите на тренировочной выборке дерево решений из библиотеки `sklearn` (`DecisionTreeClassifier`) с максимальной глубиной 8. В качестве критерия информативности используйте энтропию Шеннона, минимальное число объектов в листе (количество объектов, при которых дерево прекратит делиться и образуется лист) — 10.
#
# Также позаботьтесь о воспроизводимости результатов, установив конкретное значение `random_state` (например, число 42).
#
# Сделайте предсказания для тренировочной и тестовой выборок. Рассчитайте значение целевой метрики на каждой из выборок.
#
# Сравните результат с полученными ранее. Сделайте вывод.

# %% [markdown]
# **Критерии оценивания:**
# - Задание выполнено верно, учтены все условия (**1 балла**):
#     * построена модель дерева решений с заданными в условии задачи параметрами;
#     * с помощью полученной модели сформированы предсказания для тренировочной и тестовой выборок;
#     * приведён расчёт выбранной метрики на тренировочных и тестовых данных (метрика должна быть выбрана корректно);
#     * приведён небольшой вывод по полученным результатам, в котором содержится корректный ответ на поставленный в задании вопрос.
#
# - Задание выполнено неверно, не учтено одно или несколько условий (**0 баллов**).

# %%
# Ваш код здесь

# создаём объект класса DecisionTreeClassifier с энтропией Шеннона
dt_clf = tree.DecisionTreeClassifier(
    max_depth=8,                    # максимальная глубина дерева
    criterion='entropy',            # критерий информативности
    min_samples_leaf=10,            # минимальное число объектов в листе
    random_state=42                 # генератор случайных чисел
)

# обучаем дерево решений по алгоритму CART с ограничением его длины
dt_clf.fit(X_train, y_train);

# делаем предсказание класса для обученной модели на тренировочной выборке
y_train_pred_dt_clf = dt_clf.predict(X_train)

# делаем предсказание класса для обученной модели на тестовой выборке
y_test_pred_dt_clf = dt_clf.predict(X_test)

## вывод отчета о метриках классификации
# ТРЕНИРОВОЧНАЯ ВЫБОРКА
print(f'Train data "F1 score": {metrics.f1_score(y_train, y_train_pred_dt_clf):.3f}')
print(metrics.classification_report(y_train, y_train_pred_dt_clf))

# ТЕСТОВАЯ ВЫБОРКА
print(f'Test data "F1 score": {metrics.f1_score(y_test, y_test_pred_dt_clf):.3f}')
print(metrics.classification_report(y_test, y_test_pred_dt_clf))
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=8, min_samples_leaf=10,
#                        random_state=42)
# Train data "F1 score": 0.717
#               precision    recall  f1-score   support
#
#            0       0.85      0.92      0.88      1271
#            1       0.80      0.65      0.72       610
#
#     accuracy                           0.83      1881
#    macro avg       0.82      0.79      0.80      1881
# weighted avg       0.83      0.83      0.83      1881
#
# Test data "F1 score": 0.640
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85       424
#            1       0.71      0.58      0.64       204
#
#     accuracy                           0.79       628
#    macro avg       0.76      0.73      0.74       628
# weighted avg       0.78      0.79      0.78       628

# %% [markdown]
# > Ваши выводы и рассуждения — *здесь*
#
# Модель значительно улучшено при применении ограничений, как с точки зрения целевой метрики, так и других метрик

# %% [markdown]
# ### Задание 8.3. (1 балл)
#
# Давайте воспользуемся случайным лесом.
#
# Постройте случайный лес (`RandomForestClassifier`) из 500 деревьев с максимальной глубиной 8. Критерий информативности — энтропия Шеннона, минимальное число объектов в листе (количество объектов, при которых дерево прекратит делиться и образуется лист) — 10.
#
# Также позаботьтесь о воспроизводимости результатов, установив конкретное значение значение `random_state` (например, число 42).
#
# Сделайте предсказания для тренировочной и тестовой выборок. Рассчитайте значение целевой метрики на каждой из выборок.
#
# Сравните качество одного дерева решений с качеством случайного леса на тестовой выборке. Смогли ли вы улучшить метрику?

# %% [markdown]
# **Критерии оценивания:**
# - Задание выполнено верно, учтены все условия (**1 балл**):
#     * построена модель дерева решений с заданными в условии задачи параметрами;
#     * с помощью полученной модели сформированы предсказания для тренировочной и тестовой выборок;
#     * приведён расчёт выбранной метрики на тренировочных и тестовых данных (метрика должна быть выбрана корректно);
#     * приведён небольшой вывод по полученным результатам, в котором содержится корректный ответ на поставленный в задании вопрос.
#
# - Задание выполнено неверно, не учтено одно или несколько условий (**0 баллов**).

# %%
# Ваш код здесь
# создаём объект класса RandomForestClassifier с энтропией Шеннона
rf_clf = ensemble.RandomForestClassifier(
    n_estimators=500,               # число деревьев
    max_depth=8,                    # максимальная глубина дерева
    criterion='entropy',            # критерий информативности
    min_samples_leaf=10,            # минимальное число объектов в листе
    random_state=42                 # генератор случайных чисел
)

# обучаем "случайный лес" с ограничением его длины
rf_clf.fit(X_train, y_train);

# делаем предсказание класса для обученной модели на тренировочной выборке
y_train_pred_rf_clf = rf_clf.predict(X_train)

# делаем предсказание класса для обученной модели на тестовой выборке
y_test_pred_rf_clf = rf_clf.predict(X_test)

## вывод отчета о метриках классификации
# ТРЕНИРОВОЧНАЯ ВЫБОРКА
print(f'Train data "F1 score": {metrics.f1_score(y_train, y_train_pred_rf_clf):.3f}')
print(metrics.classification_report(y_train, y_train_pred_rf_clf))

# ТЕСТОВАЯ ВЫБОРКА
print(f'Test data "F1 score": {metrics.f1_score(y_test, y_test_pred_rf_clf):.3f}')
print(metrics.classification_report(y_test, y_test_pred_rf_clf))
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=8, min_samples_leaf=10,
#                        n_estimators=500, random_state=42)
# Train data "F1 score": 0.736
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90      1271
#            1       0.86      0.64      0.74       610
#
#     accuracy                           0.85      1881
#    macro avg       0.85      0.80      0.82      1881
# weighted avg       0.85      0.85      0.84      1881
#
# Test data "F1 score": 0.656
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86       424
#            1       0.75      0.58      0.66       204
#
#     accuracy                           0.80       628
#    macro avg       0.78      0.74      0.76       628
# weighted avg       0.80      0.80      0.79       628

# %% [markdown]
# > Ваши выводы и рассуждения — *здесь*
#
#  "случайный лес" дополнительно улучшает классическую модель , метрика, как целевая, так и остальные улучшены почти на +-10%

# %% [markdown]
# ### Задание 8.4. (2 балла)
#
# Мы на финишной прямой.
#
#
# Попробуйте подобрать значение порога вероятности, при котором наблюдается наибольшее значение целевой метрики на тестовой выборке. **Используйте ту модель (из рассмотренных ранее), которая показала наилучшее качество на тестовой выборке.**
#
#
# В качестве порога вероятности используйте значения из следующего диапазона:
#
# `thresholds = np.arange(0.1, 1, 0.05)`
#
# Напомним алгоритм, как определить оптимальный порог вероятности:
# * Предсказать вероятности оттока для каждого клиента из тестовой выборки.
# * В цикле перебрать значения порогов вероятности threshold:
#     * Сделать предсказание класса по принципу: если вероятность > threshold, то отнести объект к классу 1, в противном случае — к классу 0.
#     * Рассчитать метрику и занести её в заранее созданный список.
#
# Для реализации алгоритма подбора вы можете воспользоваться шаблоном кода, приведённым ниже:
#
# ```python
# # Делаем предсказание вероятности оттока для каждого клиента из тестовой выборки
# y_test_proba_pred = pd.Series(model.predict_proba(X_test_poly)[:, 1])
# # Инициализируем список, куда будем сохранять метрики.
# scores = []
# # Задаём значения порогов вероятности
# thresholds = np.arange(0.1, 1, 0.05)
# # В цикле перебираем значения порогов вероятности
# for threshold in thresholds:
#     # Делаем предсказание
#     y_test_pred_poly = y_test_proba_pred.apply(lambda x: 1 if x > threshold else 0)
#     # Рассчитываем метрику
#     score = # код для вычисления метрики
#     # Добавляем результат в список
#     scores.append(score)
# ```
#
# Постройте график зависимости целевой метрики от порога вероятности. На основе построенного графика определите порог вероятности, которому соответствует наибольшее значение целевой метрики на тестовой выборке.
#
# Сделайте предсказание классов с подобранным оптимальным порогом вероятности. Рассчитайте значение целевой метрики на тестовой выборке и сравните полученный результат с полученными ранее.
#
# Напишите небольшой вывод о проделанной работе, указав в нём, какая из рассмотренных нами моделей показала наилучший результат.
#
# > **Примечание.** Помните о том, что в реальных задачах (а мы решали задачу на реальных данных) мы практически никогда не сможем получить значения метрик, близкие к 1. Если в задаче прогнозирования оттока ваша метрика превышает хотя бы значения 0.6-0.7, вашу модель уже можно считать хорошей и можно говорить о том, что она успешно справляется с задачей.

# %%
# Ваш код здесь

# нас интересует только вероятность класса (второй столбец)
y_test_proba_pred = rf_clf.predict_proba(X_test)[:, 1]

# для удобства завернём numpy-массив в Pandas Series
y_test_proba_pred = pd.Series(y_test_proba_pred)

# создаём списки, в которых будем хранить значения метрик 
recall_scores = []
precision_scores = []
f1_scores = []

# генерируем набор вероятностных порогов в диапазоне от 0.1 до 1
thresholds = np.arange(0.1, 1, 0.05)

# в цикле будем перебирать сгенерированные пороги
for threshold in thresholds:
    # клиентов, для которых вероятность ухода > threshold, относим к классу 1
    # в противном случае — к классу 0
    y_pred = y_test_proba_pred.apply(lambda x: 1 if x > threshold else 0)
    
    # считаем метрики и добавляем их в списки
    recall_scores.append(metrics.recall_score(y_test, y_pred))
    precision_scores.append(metrics.precision_score(y_test, y_pred))
    f1_scores.append(metrics.f1_score(y_test, y_pred))

# визуализируем метрики при различных threshold
fig, ax = plt.subplots(figsize=(12, 6)) # фигура + координатная плоскость

# строим линейный график зависимости recall от threshold
ax.plot(thresholds, recall_scores, label='Recall')

# строим линейный график зависимости precision от threshold
ax.plot(thresholds, precision_scores, label='Precision')

# строим линейный график зависимости F1 от threshold
ax.plot(thresholds, f1_scores, label='F1-score')

# задаём графику название и подписываем оси
ax.set(title='Recall / Precision / F1 dependence on the threshold',
    xlabel='Probability threshold',
    ylabel='Score'
)

# устанавливаем отметки по оси x
ax.set_xticks(thresholds) 

# отображаем легенду
ax.legend();

# %%
# задаём оптимальный порог вероятностей
threshold_opt = 0.35

# клиентов, вероятность ухода которых > 0.35 относим к классу 1, в противном случае — к классу 0
# делаем предсказание на тренировочной выборке
y_train_proba_pred = rf_clf.predict_proba(X_train)[:, 1]
y_train_proba_pred = pd.Series(y_train_proba_pred)
y_train_pred_rf_clf_opt = y_train_proba_pred.apply(lambda x: 1 if x > threshold_opt else 0)

# делаем предсказание на тестовой выборке
y_test_pred_rf_clf_opt = y_test_proba_pred.apply(lambda x: 1 if x > threshold_opt else 0)

## вывод отчета о метриках классификации
# ТРЕНИРОВОЧНАЯ ВЫБОРКА
print(f'Train data "Accuracy": {metrics.accuracy_score(y_train, y_train_pred_rf_clf_opt):.3f}')
print(f'Train data "Precision": {metrics.precision_score(y_train, y_train_pred_rf_clf_opt):.3f}')
print(f'Train data "Recall": {metrics.recall_score(y_train, y_train_pred_rf_clf_opt):.3f}')
print(f'Train data "F1 score": {metrics.f1_score(y_train, y_train_pred_rf_clf_opt):.3f}')
print(metrics.classification_report(y_train, y_train_pred_rf_clf_opt))

# ТЕСТОВАЯ ВЫБОРКА
print(f'Test data "Accuracy": {metrics.accuracy_score(y_test, y_test_pred_rf_clf_opt):.3f}')
print(f'Test data "Precision": {metrics.precision_score(y_test, y_test_pred_rf_clf_opt):.3f}')
print(f'Test data "Recall": {metrics.recall_score(y_test, y_test_pred_rf_clf_opt):.3f}')
print(f'Test data "F1 score": {metrics.f1_score(y_test, y_test_pred_rf_clf_opt):.3f}')
print(metrics.classification_report(y_test, y_test_pred_rf_clf_opt))
# Out:
# Train data "Accuracy": 0.841
# Train data "Precision": 0.729
# Train data "Recall": 0.808
# Train data "F1 score": 0.767
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88      1271
#            1       0.73      0.81      0.77       610
#
#     accuracy                           0.84      1881
#    macro avg       0.82      0.83      0.82      1881
# weighted avg       0.85      0.84      0.84      1881
#
# Test data "Accuracy": 0.782
# Test data "Precision": 0.635
# Test data "Recall": 0.775
# Test data "F1 score": 0.698
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83       424
#            1       0.63      0.77      0.70       204
#
#     accuracy                           0.78       628
#    macro avg       0.76      0.78      0.76       628
# weighted avg       0.80      0.78      0.79       628

# %% [markdown]
# > Ваши выводы и рассуждения — *здесь*
#
# Поскольку начиная с вероятности 0.35 визуально наблюдается максимум 𝐹1 меры - целевой метрики, это значение является "переломным". Перебор других значений threshold_opt, отличных от 0.35, не привел к улучшению результатов по остальным метрикам, включая целевую. При вероятности 0.35 достигаются максимальные значения всех метрик в совокупности.
#
# При выбранном значении вероятности и модели "случайный лес" предсказание улучшено еще на почти 10%.

# %% [markdown]
# ### Задание 8.5. (1 балл)
#
# Наконец, финальная задача.
#
# У нашего банка есть некоторый клиент, назовём его Василием. В базе данных банка хранятся следующие данные о Василии:
#
# ```python
# {
#     'CreditScore': [601.0],
#     'Gender': ['Male'],
#     'Age': [42.0],
#     'Tenure': [1.0],
#     'Balance': [98495.72],
#     'NumOfProducts': [1.0],
#     'HasCrCard': [1.0],
#     'IsActiveMember': [0.0],
#     'EstimatedSalary': [40014.76]
# }
# ```
#
# С помощью наилучшей модели спрогнозируйте вероятность того, что Василий откажется от услуг банка.
#
# > **Примечание.** Учтите, что для предсказания необходимо преобразовать данные к тому формату, на котором обучалась модель, то есть:
# * добавить признаки дополнительные признаки;
# * произвести кодирование категориальных признаков;
# * произвести масштабирование признаков (если ваша модель обучалась на масштабированных данных) с помощью того же скейлера, который вы использовали при обучении модели;
# * сгенерировать полиномиальные признаки.

# %% [markdown]
# **Критерии оценивания:**
# - Задание выполнено верно, учтены все условия (**1 балл**):
#     * сформирован DataFrame на основе предоставленного словаря;
#     * произведены преобразования данных, необходимые для работы модели;
#     * предсказана вероятность оттока клиента (вероятность принадлежности к классу 1).
#
# - Задание выполнено неверно, не учтено одно или несколько условий (**0 баллов**).

# %%
# Ваш код здесь

# создаём объект Series, конвертируем в Dataframe,
# транспонируем из вертикального представления в горизонтальный
new_client = pd.DataFrame(pd.Series({
    'CreditScore': [601.0],
    'Gender': ['Male'],
    'Age': [42.0],
    'Tenure': [1.0],
    'Balance': [98495.72],
    'NumOfProducts': [1.0],
    'HasCrCard': [1.0],
    'IsActiveMember': [0.0],
    'EstimatedSalary': [40014.76]
},
name='Vasiliy')
).T

# смотрим результат
new_client
# Out:
#         CreditScore  Gender     Age Tenure     Balance NumOfProducts  \
# Vasiliy     [601.0]  [Male]  [42.0]  [1.0]  [98495.72]         [1.0]
#
#         HasCrCard IsActiveMember EstimatedSalary
# Vasiliy     [1.0]          [0.0]      [40014.76]

# %%
# "очистка" значений
for col in new_client.columns:
    new_client[col] = new_client[col].apply(lambda x: str(x).strip('[').strip(']'))
    new_client[col] = new_client[col].apply(lambda x: str(x).replace("'", ''))

# перекодируем единичный текстовый категориальный признак 'Gender' в бинарный столбец (1 — 'Male', 0 — 'Female')
new_client['Gender'] = new_client['Gender'].apply(lambda x: 1 if x=='Male' else 0)

# преобразование типов к численному
for col in new_client.columns:
    new_client[col] = pd.to_numeric(new_client[col])

# преобразование типов признаков в соответствии с признаками в датасете churn_data
new_client[['CreditScore', 'Gender', 'Age', 'Tenure', 'NumOfProducts', 'HasCrCard', 'IsActiveMember']] = new_client[[
    'CreditScore', 'Gender', 'Age', 'Tenure', 'NumOfProducts', 'HasCrCard', 'IsActiveMember']].apply(int)
new_client[['Balance', 'EstimatedSalary']] = new_client[[
    'Balance', 'EstimatedSalary']].astype(float)

# формирование дополнительных признаков
new_client['BalanceSalaryRatio'] = new_client['Balance'] / new_client['EstimatedSalary']
new_client['TenureByAge'] = new_client['Tenure'] / (new_client['Age'])
new_client['CreditScoreGivenAge'] = new_client['CreditScore'] / (new_client['Age'])

# смотрим результат
new_client
new_client.info()
# Out:
#          CreditScore  Gender  Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# Vasiliy          601       1   42       1  98495.72              1          1
#
#          IsActiveMember  EstimatedSalary  BalanceSalaryRatio  TenureByAge  \
# Vasiliy               0         40014.76            2.461485      0.02381
#
#          CreditScoreGivenAge
# Vasiliy            14.309524
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, Vasiliy to Vasiliy
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CreditScore          1 non-null      int64
#  1   Gender               1 non-null      int64
#  2   Age                  1 non-null      int64
#  3   Tenure               1 non-null      int64
#  4   Balance              1 non-null      float64
#  5   NumOfProducts        1 non-null      int64
#  6   HasCrCard            1 non-null      int64
#  7   IsActiveMember       1 non-null      int64
#  8   EstimatedSalary      1 non-null      float64
#  9   BalanceSalaryRatio   1 non-null      float64
#  10  TenureByAge          1 non-null      float64
#  11  CreditScoreGivenAge  1 non-null      float64
# dtypes: float64(5), int64(7)
# memory usage: 104.0+ bytes

# %%
## предсказание на основе модели RandomForestClassifier
# делаем предсказание вероятностей
y_new_client_proba_predict_rf_clf = rf_clf.predict_proba(new_client)

# выводим предсказанные вероятности
print(f'Predicted probabilities: {np.round(y_new_client_proba_predict_rf_clf, 2)}')

# делаем предсказание класса
y_new_client_predict_rf_clf = rf_clf.predict(new_client)

# выводим предсказанный класс
print(f'Predicted class: {y_new_client_predict_rf_clf}')

# выводим вердикт по клиенту
if y_new_client_predict_rf_clf:
    print(f'Client will exit with probability {(y_new_client_proba_predict_rf_clf[0, 1] * 100):.2f}%')
else:
    print(f'Client will stay with probability {(y_new_client_proba_predict_rf_clf[0, 0] * 100):.2f}%')
# Out:
# Predicted probabilities: [[0.39 0.61]]
# Predicted class: [1]
# Client will exit with probability 61.43%

# %%
## предсказание на основе модели логистической регрессии с SGD
# производим нормализацию тренировочной выборки
new_client_scaled = scaler.transform(new_client)

# генерируем полиномиальные признаки для тренировочной выборки
new_client_scaled_poly = poly.transform(new_client_scaled)

# делаем предсказание вероятностей
y_new_client_proba_predict_lr_poly = lr_poly.predict_proba(new_client_scaled_poly)

# выводим предсказанные вероятности
print(f'Predicted probabilities: {np.round(y_new_client_proba_predict_lr_poly, 2)}')

# делаем предсказание класса
y_new_client_pred_lr_poly = lr_poly.predict(new_client_scaled_poly)

# выводим предсказанный класс
print(f'Predicted class: {y_new_client_pred_lr_poly}')

# выводим вердикт по клиенту
if y_new_client_pred_lr_poly:
    print(f'Client will exit with probability {(y_new_client_proba_predict_lr_poly[0, 1] * 100):.2f}%')
else:
    print(f'Client will stay with probability {(y_new_client_proba_predict_lr_poly[0, 0] * 100):.2f}%')
# Out:
# Predicted probabilities: [[0.31 0.69]]
# Predicted class: [1]
# Client will exit with probability 68.57%

# %% [markdown]
# На основании модели случайного леса вероятность ухода клиента составляет 61.43%. На основании модели логистической регрессии со стохастическим градиентным спуском вероятность ухода клиента составляет 68.57%.
#
# Общий вывод:
# Если сравнивать модели логистической регрессии, то однозначно выигрывает модель логистической регрессии с полиномиальными коэффициентами.
# Если сравнивать "древесные" модели, то однозначно выигрывает модель "случайного леса".
# Если сравнивать результаты метрик логистической регрессии с полиномиальными коэффициентами и модели "случайного леса", то их результаты сопоставимы.
